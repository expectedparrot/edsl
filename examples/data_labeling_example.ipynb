# %% [markdown]
# # Data labeling with `edsl`
# This notebook shows how to use `edsl` to automate data labeling and content analysis. In a series of steps we design and conduct an analysis of customer service tickets for a transportation app.

# %% [markdown]
# ## Technical setup
# This section contains code for importing the basic `edsl` tools that we will use to design and conduct our content analysis. The tools allow us to define the ticket content review as a survey of questions that we deliver to a specified lanaguage model, with carefully constructed directions about the task to be done and the desired format of results.

# %%
# ! pip install edsl

# %%
from edsl.questions import QuestionMultipleChoice, QuestionCheckBox, QuestionFreeText, QuestionList, QuestionYesNo, QuestionLinearScale
from edsl import Survey, Scenario, Model

# %% [markdown]
# We can see the available models and choose one or more of them:

# %%
Model.available()
# Out:
# ['claude-3-haiku-20240307',
#  'claude-3-opus-20240229',
#  'claude-3-sonnet-20240229',
#  'dbrx-instruct',
#  'gemini_pro',
#  'gpt-3.5-turbo',
#  'gpt-4-1106-preview',
#  'llama-2-13b-chat-hf',
#  'llama-2-70b-chat-hf',
#  'mixtral-8x7B-instruct-v0.1']

# %%
model = Model('gpt-4-1106-preview')

# %% [markdown]
# ## Assessment design
# We start by identifying some content for review. Content can be created or imported from existing files. For purposes of this demo, we'll import a set of hypothetical customer service ticket comments for a transportation app:

# %%
tickets = [
    "I just realized I left my phone in the car on my last ride. Can you help me get it back?",
    "I'm unhappy with my recent experience. The driver was very rude and unprofessional.",
    "I was charged more than the estimated fare for my trip yesterday. Can you explain why?",
    "The car seat provided was not properly installed, and I felt my child was at risk. Please ensure driver training.",
    "My driver took a longer route than necessary, resulting in a higher fare. I request a fare adjustment.",
    "I had a great experience with my driver today! Very friendly and efficient service.",
    "I'm concerned about the vehicle's cleanliness. It was not up to the standard I expect.",
    "The app keeps crashing every time I try to book a ride. Please fix this issue.",
    "My driver was exceptional - safe driving, polite, and the car was spotless. Kudos!",
    "I felt unsafe during my ride due to the driver's erratic behavior. This needs to be addressed immediately.",
    "The driver refused to follow my preferred route, which is shorter. I'm not satisfied with the service.",
    "Impressed with the quick response to my ride request and the driver's professionalism.",
    "I was charged for a ride I never took. Please refund me as soon as possible.",
    "The promo code I tried to use didn't work. Can you assist with this?",
    "There was a suspicious smell in the car, and I'm worried about hygiene standards.",
    "My driver was very considerate, especially helping me with my luggage. Appreciate the great service!",
    "The app's GPS seems inaccurate. It directed the driver to the wrong pick-up location.",
    "I want to compliment my driver's excellent navigation and time management during rush hour.",
    "The vehicle didn't match the description in the app. It was confusing and concerning.",
    "I faced an issue with payment processing after my last ride. Can you look into this?",
]

# %% [markdown]
# Next we identify some dimensions for our ticket review, constructed as a set of questions that we'll administer to an AI with the ticket contents. The questions could include the following:
# <i>
#     Check all of the issues mentioned in this ticket: safety, cleanliness, driver performance, etc.
#     What is the primary issue in this ticket?
#     If the primary issue is safety, was there an accident where someone was hurt?
#     What is the sentiment of this ticket?
#     Does the customer ask for a refund?
#     On a scale from 1 (lowest) to 5 (highest), what is the priority level of this ticket?
# </i>

# %% [markdown]
# The code that we use specifies the questions, question types and answer options, and allows us to select a particular language model. The questions are written in `edsl` format so that they can be sent to an AI and edited or replaced with questions of your choice.

# %%
question_issues = QuestionCheckBox(
    question_name="issues",
    question_text="Check all of the issues mentioned in this ticket: {{ticket}}",
    question_options=[
        "safety", 
        "cleanliness", 
        "driver performance", 
        "GPS/route", 
        "lost item", 
        "other"]
)

# %%
question_primary_issue = QuestionFreeText(
    question_name="primary_issue",
    question_text="What is the primary issue in this ticket? Ticket: {{ticket}}",
    allow_nonresponse=False,
)

# %%
question_accident = QuestionMultipleChoice(
    question_name="accident",
    question_text="If the primary issue in this ticket is safety, was there an accident where someone was hurt? Ticket: {{ticket}}",
    question_options=["Yes", "No", "Not applicable"]
)

# %%
question_sentiment = QuestionMultipleChoice(
    question_name="sentiment",
    question_text="What is the sentiment of this ticket? Ticket: {{ticket}}",
    question_options=[
        "Very positive",
        "Somewhat positive",
        "Neutral",
        "Somewhat negative",
        "Very negative"
    ]
)

# %%
question_refund = QuestionYesNo(
    question_name="refund",
    question_text="Does the customer ask for a refund in this ticket? Ticket: {{ticket}}"
)

# %%
question_priority = QuestionLinearScale(
    question_name="priority",
    question_text="On a scale from 0 (lowest) to 5 (highest), what is the priority level of this ticket? Ticket: {{ticket}}",
    question_options=[0,1,2,3,4,5]
)

# %%
survey = Survey(
    questions=[
        question_issues,
        question_primary_issue,
        question_accident,
        question_sentiment,
        question_refund,
        question_priority
    ]
)

# %% [markdown]
# We can also review our questions in a readable format, or export them as a survey to use with human respondents or at other survey platforms:

# %%
survey.print()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Questions                                                                                                       ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Question Name ┃ Question Type ┃ Question Text                        ┃ Options                              ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ issues        │ checkbox      │ Check all of the issues mentioned in │ safety, cleanliness, driver          │ │
# │ │               │               │ this ticket: {{ticket}}              │ performance, GPS/route, lost item,   │ │
# │ │               │               │                                      │ other                                │ │
# │ └───────────────┴───────────────┴──────────────────────────────────────┴──────────────────────────────────────┘ │
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓      │
# │ ┃ Question Name ┃ Question Type ┃ Question Text                                                ┃ Options ┃      │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩      │
# │ │ primary_issue │ free_text     │ What is the primary issue in this ticket? Ticket: {{ticket}} │ None    │      │
# │ └───────────────┴───────────────┴──────────────────────────────────────────────────────────────┴─────────┘      │
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Question Name ┃ Question Type   ┃ Question Text                                   ┃ Options                 ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ accident      │ multiple_choice │ If the primary issue in this ticket is safety,  │ Yes, No, Not applicable │ │
# │ │               │                 │ was there an accident where someone was hurt?   │                         │ │
# │ │               │                 │ Ticket: {{ticket}}                              │                         │ │
# │ └───────────────┴─────────────────┴─────────────────────────────────────────────────┴─────────────────────────┘ │
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Question Name ┃ Question Type   ┃ Question Text                       ┃ Options                             ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ sentiment     │ multiple_choice │ What is the sentiment of this       │ Very positive, Somewhat positive,   │ │
# │ │               │                 │ ticket? Ticket: {{ticket}}          │ Neutral, Somewhat negative, Very    │ │
# │ │               │                 │                                     │ negative                            │ │
# │ └───────────────┴─────────────────┴─────────────────────────────────────┴─────────────────────────────────────┘ │
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓ │
# │ ┃ Question Name ┃ Question Type ┃ Question Text                                                     ┃ Options ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩ │
# │ │ refund        │ yes_no        │ Does the customer ask for a refund in this ticket? Ticket:        │ Yes, No │ │
# │ │               │               │ {{ticket}}                                                        │         │ │
# │ └───────────────┴───────────────┴───────────────────────────────────────────────────────────────────┴─────────┘ │
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Question Name ┃ Question Type ┃ Question Text                                            ┃ Options          ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩ │
# │ │ priority      │ linear_scale  │ On a scale from 0 (lowest) to 5 (highest), what is the   │ 0, 1, 2, 3, 4, 5 │ │
# │ │               │               │ priority level of this ticket? Ticket: {{ticket}}        │                  │ │
# │ └───────────────┴───────────────┴──────────────────────────────────────────────────────────┴──────────────────┘ │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
survey
# Out:
# Survey(questions=[QuestionCheckBox(question_name = 'issues', question_text = 'Check all of the issues mentioned in this ticket: {{ticket}}', min_selections = None, max_selections = None, question_options = ['safety', 'cleanliness', 'driver performance', 'GPS/route', 'lost item', 'other'], short_names_dict = {}), QuestionFreeText(question_name = 'primary_issue', question_text = 'What is the primary issue in this ticket? Ticket: {{ticket}}', allow_nonresponse = False), QuestionMultipleChoice(question_name = 'accident', question_text = 'If the primary issue in this ticket is safety, was there an accident where someone was hurt? Ticket: {{ticket}}', question_options = ['Yes', 'No', 'Not applicable'], short_names_dict = {}), QuestionMultipleChoice(question_name = 'sentiment', question_text = 'What is the sentiment of this ticket? Ticket: {{ticket}}', question_options = ['Very positive', 'Somewhat positive', 'Neutral', 'Somewhat negative', 'Very negative'], short_names_dict = {}), QuestionYesNo(question_name = 'refund', question_text = 'Does the customer ask for a refund in this ticket? Ticket: {{ticket}}', question_options = ['Yes', 'No'], short_names_dict = {}), QuestionLinearScale(question_name = 'priority', question_text = 'On a scale from 0 (lowest) to 5 (highest), what is the priority level of this ticket? Ticket: {{ticket}}', question_options = [0, 1, 2, 3, 4, 5], short_names_dict = {}, option_labels = None)], name=None)

# %% [markdown]
# ## Analysis
# With our content and questions we're now ready to package our survey and deliver it to an AI. We do this by inserting the content of each ticket into each question as an independent "scenario" for review.

# %%
scenarios = [Scenario({'ticket':t}) for t in tickets]

# %%
results = survey.by(scenarios).by(model).run()

# %%
results.columns
# Out:
# ['agent.agent_name',
#  'answer.accident',
#  'answer.accident_comment',
#  'answer.issues',
#  'answer.issues_comment',
#  'answer.primary_issue',
#  'answer.priority',
#  'answer.priority_comment',
#  'answer.refund',
#  'answer.refund_comment',
#  'answer.sentiment',
#  'answer.sentiment_comment',
#  'iteration.iteration',
#  'model.frequency_penalty',
#  'model.logprobs',
#  'model.max_tokens',
#  'model.model',
#  'model.presence_penalty',
#  'model.temperature',
#  'model.top_logprobs',
#  'model.top_p',
#  'prompt.accident_system_prompt',
#  'prompt.accident_user_prompt',
#  'prompt.issues_system_prompt',
#  'prompt.issues_user_prompt',
#  'prompt.primary_issue_system_prompt',
#  'prompt.primary_issue_user_prompt',
#  'prompt.priority_system_prompt',
#  'prompt.priority_user_prompt',
#  'prompt.refund_system_prompt',
#  'prompt.refund_user_prompt',
#  'prompt.sentiment_system_prompt',
#  'prompt.sentiment_user_prompt',
#  'raw_model_response.accident_raw_model_response',
#  'raw_model_response.issues_raw_model_response',
#  'raw_model_response.primary_issue_raw_model_response',
#  'raw_model_response.priority_raw_model_response',
#  'raw_model_response.refund_raw_model_response',
#  'raw_model_response.sentiment_raw_model_response',
#  'scenario.ticket']

# %%
results.select('ticket','issues','primary_issue','accident','sentiment','refund','priority').print()
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ scenario         ┃ answer           ┃ answer          ┃ answer         ┃ answer           ┃ answer  ┃ answer    ┃
# ┃ .ticket          ┃ .issues          ┃ .primary_issue  ┃ .accident      ┃ .sentiment       ┃ .refund ┃ .priority ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━┩
# │ Impressed with   │ ['driver         │ There is no     │ Not applicable │ Very positive    │ No      │ 0         │
# │ the quick        │ performance']    │ issue reported  │                │                  │         │           │
# │ response to my   │                  │ in this ticket. │                │                  │         │           │
# │ ride request and │                  │ The customer is │                │                  │         │           │
# │ the driver's     │                  │ expressing      │                │                  │         │           │
# │ professionalism. │                  │ satisfaction    │                │                  │         │           │
# │                  │                  │ with the quick  │                │                  │         │           │
# │                  │                  │ response to     │                │                  │         │           │
# │                  │                  │ their ride      │                │                  │         │           │
# │                  │                  │ request and the │                │                  │         │           │
# │                  │                  │ driver's        │                │                  │         │           │
# │                  │                  │ professionalis… │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I want to        │ ['driver         │ The primary     │ No             │ Very positive    │ No      │ 0         │
# │ compliment my    │ performance',    │ issue in this   │                │                  │         │           │
# │ driver's         │ 'GPS/route']     │ ticket is not a │                │                  │         │           │
# │ excellent        │                  │ problem but a   │                │                  │         │           │
# │ navigation and   │                  │ positive        │                │                  │         │           │
# │ time management  │                  │ feedback        │                │                  │         │           │
# │ during rush      │                  │ regarding the   │                │                  │         │           │
# │ hour.            │                  │ driver's        │                │                  │         │           │
# │                  │                  │ excellent       │                │                  │         │           │
# │                  │                  │ navigation and  │                │                  │         │           │
# │                  │                  │ time management │                │                  │         │           │
# │                  │                  │ skills during   │                │                  │         │           │
# │                  │                  │ rush hour.      │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I faced an issue │ ['other']        │ The primary     │ Not applicable │ Somewhat         │ No      │ 4         │
# │ with payment     │                  │ issue in the    │                │ negative         │         │           │
# │ processing after │                  │ ticket is a     │                │                  │         │           │
# │ my last ride.    │                  │ problem with    │                │                  │         │           │
# │ Can you look     │                  │ payment         │                │                  │         │           │
# │ into this?       │                  │ processing that │                │                  │         │           │
# │                  │                  │ occurred after  │                │                  │         │           │
# │                  │                  │ the customer's  │                │                  │         │           │
# │                  │                  │ last ride.      │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ My driver was    │ ['driver         │ There is no     │ No             │ Very positive    │ No      │ 0         │
# │ very             │ performance']    │ issue reported  │                │                  │         │           │
# │ considerate,     │                  │ in this ticket. │                │                  │         │           │
# │ especially       │                  │ The customer is │                │                  │         │           │
# │ helping me with  │                  │ expressing      │                │                  │         │           │
# │ my luggage.      │                  │ appreciation    │                │                  │         │           │
# │ Appreciate the   │                  │ for the         │                │                  │         │           │
# │ great service!   │                  │ considerate     │                │                  │         │           │
# │                  │                  │ service         │                │                  │         │           │
# │                  │                  │ provided by the │                │                  │         │           │
# │                  │                  │ driver.         │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ My driver took a │ ['driver         │ The primary     │ No             │ Somewhat         │ No      │ 3         │
# │ longer route     │ performance',    │ issue in the    │                │ negative         │         │           │
# │ than necessary,  │ 'GPS/route']     │ ticket is that  │                │                  │         │           │
# │ resulting in a   │                  │ the customer is │                │                  │         │           │
# │ higher fare. I   │                  │ reporting that  │                │                  │         │           │
# │ request a fare   │                  │ the driver took │                │                  │         │           │
# │ adjustment.      │                  │ a longer route  │                │                  │         │           │
# │                  │                  │ than necessary, │                │                  │         │           │
# │                  │                  │ which led to an │                │                  │         │           │
# │                  │                  │ increased fare. │                │                  │         │           │
# │                  │                  │ The customer is │                │                  │         │           │
# │                  │                  │ requesting a    │                │                  │         │           │
# │                  │                  │ fare adjustment │                │                  │         │           │
# │                  │                  │ due to this     │                │                  │         │           │
# │                  │                  │ issue.          │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I just realized  │ ['lost item']    │ The primary     │ Not applicable │ Somewhat         │ No      │ 4         │
# │ I left my phone  │                  │ issue in this   │                │ negative         │         │           │
# │ in the car on my │                  │ ticket is that  │                │                  │         │           │
# │ last ride. Can   │                  │ the customer    │                │                  │         │           │
# │ you help me get  │                  │ has left their  │                │                  │         │           │
# │ it back?         │                  │ phone in the    │                │                  │         │           │
# │                  │                  │ car on their    │                │                  │         │           │
# │                  │                  │ last ride and   │                │                  │         │           │
# │                  │                  │ is seeking      │                │                  │         │           │
# │                  │                  │ assistance to   │                │                  │         │           │
# │                  │                  │ retrieve it.    │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The app's GPS    │ ['GPS/route']    │ The primary     │ No             │ Somewhat         │ No      │ 4         │
# │ seems            │                  │ issue in the    │                │ negative         │         │           │
# │ inaccurate. It   │                  │ ticket is that  │                │                  │         │           │
# │ directed the     │                  │ the app's GPS   │                │                  │         │           │
# │ driver to the    │                  │ is providing    │                │                  │         │           │
# │ wrong pick-up    │                  │ inaccurate      │                │                  │         │           │
# │ location.        │                  │ directions,     │                │                  │         │           │
# │                  │                  │ leading the     │                │                  │         │           │
# │                  │                  │ driver to an    │                │                  │         │           │
# │                  │                  │ incorrect       │                │                  │         │           │
# │                  │                  │ pick-up         │                │                  │         │           │
# │                  │                  │ location.       │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The driver       │ ['driver         │ The primary     │ No             │ Somewhat         │ No      │ 2         │
# │ refused to       │ performance',    │ issue in this   │                │ negative         │         │           │
# │ follow my        │ 'GPS/route']     │ ticket is that  │                │                  │         │           │
# │ preferred route, │                  │ the driver      │                │                  │         │           │
# │ which is         │                  │ refused to      │                │                  │         │           │
# │ shorter. I'm not │                  │ follow the      │                │                  │         │           │
# │ satisfied with   │                  │ customer's      │                │                  │         │           │
# │ the service.     │                  │ preferred       │                │                  │         │           │
# │                  │                  │ route, which    │                │                  │         │           │
# │                  │                  │ the customer    │                │                  │         │           │
# │                  │                  │ believes is     │                │                  │         │           │
# │                  │                  │ shorter,        │                │                  │         │           │
# │                  │                  │ leading to      │                │                  │         │           │
# │                  │                  │ dissatisfaction │                │                  │         │           │
# │                  │                  │ with the        │                │                  │         │           │
# │                  │                  │ service         │                │                  │         │           │
# │                  │                  │ provided.       │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The app keeps    │ ['other']        │ The primary     │ No             │ Very negative    │ No      │ 4         │
# │ crashing every   │                  │ issue reported  │                │                  │         │           │
# │ time I try to    │                  │ in the ticket   │                │                  │         │           │
# │ book a ride.     │                  │ is that the     │                │                  │         │           │
# │ Please fix this  │                  │ application is  │                │                  │         │           │
# │ issue.           │                  │ crashing every  │                │                  │         │           │
# │                  │                  │ time the user   │                │                  │         │           │
# │                  │                  │ attempts to     │                │                  │         │           │
# │                  │                  │ book a ride.    │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I had a great    │ ['driver         │ There is no     │ No             │ Very positive    │ No      │ 0         │
# │ experience with  │ performance']    │ issue reported  │                │                  │         │           │
# │ my driver today! │                  │ in this ticket. │                │                  │         │           │
# │ Very friendly    │                  │ The customer is │                │                  │         │           │
# │ and efficient    │                  │ providing       │                │                  │         │           │
# │ service.         │                  │ positive        │                │                  │         │           │
# │                  │                  │ feedback about  │                │                  │         │           │
# │                  │                  │ a great         │                │                  │         │           │
# │                  │                  │ experience with │                │                  │         │           │
# │                  │                  │ a friendly and  │                │                  │         │           │
# │                  │                  │ efficient       │                │                  │         │           │
# │                  │                  │ driver.         │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I'm concerned    │ ['cleanliness']  │ The primary     │ No             │ Somewhat         │ No      │ 3         │
# │ about the        │                  │ issue in the    │                │ negative         │         │           │
# │ vehicle's        │                  │ ticket is the   │                │                  │         │           │
# │ cleanliness. It  │                  │ customer's      │                │                  │         │           │
# │ was not up to    │                  │ concern         │                │                  │         │           │
# │ the standard I   │                  │ regarding the   │                │                  │         │           │
# │ expect.          │                  │ cleanliness of  │                │                  │         │           │
# │                  │                  │ the vehicle,    │                │                  │         │           │
# │                  │                  │ which did not   │                │                  │         │           │
# │                  │                  │ meet their      │                │                  │         │           │
# │                  │                  │ expected        │                │                  │         │           │
# │                  │                  │ standard.       │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I felt unsafe    │ ['safety',       │ The primary     │ No             │ Very negative    │ No      │ 5         │
# │ during my ride   │ 'driver          │ issue in the    │                │                  │         │           │
# │ due to the       │ performance']    │ ticket is that  │                │                  │         │           │
# │ driver's erratic │                  │ the customer    │                │                  │         │           │
# │ behavior. This   │                  │ felt unsafe due │                │                  │         │           │
# │ needs to be      │                  │ to the driver's │                │                  │         │           │
# │ addressed        │                  │ erratic         │                │                  │         │           │
# │ immediately.     │                  │ behavior and is │                │                  │         │           │
# │                  │                  │ requesting      │                │                  │         │           │
# │                  │                  │ immediate       │                │                  │         │           │
# │                  │                  │ action to       │                │                  │         │           │
# │                  │                  │ address this    │                │                  │         │           │
# │                  │                  │ concern.        │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ My driver was    │ ['safety',       │ The primary     │ No             │ Very positive    │ No      │ 0         │
# │ exceptional -    │ 'cleanliness',   │ issue in this   │                │                  │         │           │
# │ safe driving,    │ 'driver          │ ticket is not a │                │                  │         │           │
# │ polite, and the  │ performance']    │ problem but     │                │                  │         │           │
# │ car was          │                  │ positive        │                │                  │         │           │
# │ spotless. Kudos! │                  │ feedback        │                │                  │         │           │
# │                  │                  │ regarding the   │                │                  │         │           │
# │                  │                  │ driver's        │                │                  │         │           │
# │                  │                  │ performance.    │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The promo code I │ ['other']        │ The primary     │ No             │ Somewhat         │ No      │ 3         │
# │ tried to use     │                  │ issue in this   │                │ negative         │         │           │
# │ didn't work. Can │                  │ ticket is that  │                │                  │         │           │
# │ you assist with  │                  │ the customer    │                │                  │         │           │
# │ this?            │                  │ attempted to    │                │                  │         │           │
# │                  │                  │ use a promo     │                │                  │         │           │
# │                  │                  │ code which did  │                │                  │         │           │
# │                  │                  │ not work, and   │                │                  │         │           │
# │                  │                  │ they are        │                │                  │         │           │
# │                  │                  │ requesting      │                │                  │         │           │
# │                  │                  │ assistance to   │                │                  │         │           │
# │                  │                  │ resolve the     │                │                  │         │           │
# │                  │                  │ issue.          │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I was charged    │ ['other']        │ The primary     │ Not applicable │ Somewhat         │ No      │ 3         │
# │ more than the    │                  │ issue in this   │                │ negative         │         │           │
# │ estimated fare   │                  │ ticket is that  │                │                  │         │           │
# │ for my trip      │                  │ the customer    │                │                  │         │           │
# │ yesterday. Can   │                  │ was charged an  │                │                  │         │           │
# │ you explain why? │                  │ amount          │                │                  │         │           │
# │                  │                  │ exceeding the   │                │                  │         │           │
# │                  │                  │ estimated fare  │                │                  │         │           │
# │                  │                  │ for their trip  │                │                  │         │           │
# │                  │                  │ and is seeking  │                │                  │         │           │
# │                  │                  │ an explanation  │                │                  │         │           │
# │                  │                  │ for the         │                │                  │         │           │
# │                  │                  │ discrepancy.    │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The vehicle      │ ['other']        │ The primary     │ No             │ Somewhat         │ No      │ 4         │
# │ didn't match the │                  │ issue in the    │                │ negative         │         │           │
# │ description in   │                  │ ticket is that  │                │                  │         │           │
# │ the app. It was  │                  │ the vehicle     │                │                  │         │           │
# │ confusing and    │                  │ that arrived    │                │                  │         │           │
# │ concerning.      │                  │ did not match   │                │                  │         │           │
# │                  │                  │ the description │                │                  │         │           │
# │                  │                  │ provided in the │                │                  │         │           │
# │                  │                  │ app, which      │                │                  │         │           │
# │                  │                  │ caused          │                │                  │         │           │
# │                  │                  │ confusion and   │                │                  │         │           │
# │                  │                  │ concern for the │                │                  │         │           │
# │                  │                  │ customer.       │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ There was a      │ ['cleanliness']  │ The primary     │ No             │ Somewhat         │ No      │ 3         │
# │ suspicious smell │                  │ issue in the    │                │ negative         │         │           │
# │ in the car, and  │                  │ ticket is a     │                │                  │         │           │
# │ I'm worried      │                  │ concern         │                │                  │         │           │
# │ about hygiene    │                  │ regarding a     │                │                  │         │           │
# │ standards.       │                  │ suspicious      │                │                  │         │           │
# │                  │                  │ smell in the    │                │                  │         │           │
# │                  │                  │ car, which has  │                │                  │         │           │
# │                  │                  │ raised worries  │                │                  │         │           │
# │                  │                  │ about the       │                │                  │         │           │
# │                  │                  │ vehicle's       │                │                  │         │           │
# │                  │                  │ hygiene         │                │                  │         │           │
# │                  │                  │ standards.      │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I was charged    │ ['other']        │ The primary     │ Not applicable │ Somewhat         │ Yes     │ 4         │
# │ for a ride I     │                  │ issue in the    │                │ negative         │         │           │
# │ never took.      │                  │ ticket is that  │                │                  │         │           │
# │ Please refund me │                  │ the customer    │                │                  │         │           │
# │ as soon as       │                  │ has been        │                │                  │         │           │
# │ possible.        │                  │ charged for a   │                │                  │         │           │
# │                  │                  │ ride they did   │                │                  │         │           │
# │                  │                  │ not take and is │                │                  │         │           │
# │                  │                  │ requesting a    │                │                  │         │           │
# │                  │                  │ prompt refund.  │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ The car seat     │ ['safety',       │ The primary     │ No             │ Very negative    │ No      │ 5         │
# │ provided was not │ 'driver          │ issue in this   │                │                  │         │           │
# │ properly         │ performance']    │ ticket is that  │                │                  │         │           │
# │ installed, and I │                  │ the car seat    │                │                  │         │           │
# │ felt my child    │                  │ provided was    │                │                  │         │           │
# │ was at risk.     │                  │ not properly    │                │                  │         │           │
# │ Please ensure    │                  │ installed,      │                │                  │         │           │
# │ driver training. │                  │ which led to    │                │                  │         │           │
# │                  │                  │ concerns about  │                │                  │         │           │
# │                  │                  │ the child's     │                │                  │         │           │
# │                  │                  │ safety. The     │                │                  │         │           │
# │                  │                  │ customer is     │                │                  │         │           │
# │                  │                  │ requesting      │                │                  │         │           │
# │                  │                  │ improved driver │                │                  │         │           │
# │                  │                  │ training to     │                │                  │         │           │
# │                  │                  │ ensure proper   │                │                  │         │           │
# │                  │                  │ installation of │                │                  │         │           │
# │                  │                  │ car seats in    │                │                  │         │           │
# │                  │                  │ the future.     │                │                  │         │           │
# ├──────────────────┼──────────────────┼─────────────────┼────────────────┼──────────────────┼─────────┼───────────┤
# │ I'm unhappy with │ ['driver         │ The primary     │ No             │ Very negative    │ No      │ 4         │
# │ my recent        │ performance']    │ issue in this   │                │                  │         │           │
# │ experience. The  │                  │ ticket is that  │                │                  │         │           │
# │ driver was very  │                  │ the customer    │                │                  │         │           │
# │ rude and         │                  │ experienced     │                │                  │         │           │
# │ unprofessional.  │                  │ rude and        │                │                  │         │           │
# │                  │                  │ unprofessional  │                │                  │         │           │
# │                  │                  │ behavior from a │                │                  │         │           │
# │                  │                  │ driver.         │                │                  │         │           │
# └──────────────────┴──────────────────┴─────────────────┴────────────────┴──────────────────┴─────────┴───────────┘

# %% [markdown]
# We can apply some lables to our table:

# %%
(results
 .select('ticket','issues','primary_issue','accident','sentiment','refund','priority')
 .print(pretty_labels={'scenario.ticket':'Ticket','answer.issues':'Issues','answer.primary_issue':'Primary issue','answer.accident':'Accident','answer.sentiment':'Sentiment','answer.refund':'Refund request','answer.priority':'Priority'})
)
# Out:
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Ticket         ┃ Issues         ┃ Primary issue   ┃ Accident       ┃ Sentiment      ┃ Refund request ┃ Priority ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ Impressed with │ ['driver       │ There is no     │ Not applicable │ Very positive  │ No             │ 0        │
# │ the quick      │ performance']  │ issue reported  │                │                │                │          │
# │ response to my │                │ in this ticket. │                │                │                │          │
# │ ride request   │                │ The customer is │                │                │                │          │
# │ and the        │                │ expressing      │                │                │                │          │
# │ driver's       │                │ satisfaction    │                │                │                │          │
# │ professionali… │                │ with the quick  │                │                │                │          │
# │                │                │ response to     │                │                │                │          │
# │                │                │ their ride      │                │                │                │          │
# │                │                │ request and the │                │                │                │          │
# │                │                │ driver's        │                │                │                │          │
# │                │                │ professionalis… │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I want to      │ ['driver       │ The primary     │ No             │ Very positive  │ No             │ 0        │
# │ compliment my  │ performance',  │ issue in this   │                │                │                │          │
# │ driver's       │ 'GPS/route']   │ ticket is not a │                │                │                │          │
# │ excellent      │                │ problem but a   │                │                │                │          │
# │ navigation and │                │ positive        │                │                │                │          │
# │ time           │                │ feedback        │                │                │                │          │
# │ management     │                │ regarding the   │                │                │                │          │
# │ during rush    │                │ driver's        │                │                │                │          │
# │ hour.          │                │ excellent       │                │                │                │          │
# │                │                │ navigation and  │                │                │                │          │
# │                │                │ time management │                │                │                │          │
# │                │                │ skills during   │                │                │                │          │
# │                │                │ rush hour.      │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I faced an     │ ['other']      │ The primary     │ Not applicable │ Somewhat       │ No             │ 4        │
# │ issue with     │                │ issue in the    │                │ negative       │                │          │
# │ payment        │                │ ticket is a     │                │                │                │          │
# │ processing     │                │ problem with    │                │                │                │          │
# │ after my last  │                │ payment         │                │                │                │          │
# │ ride. Can you  │                │ processing that │                │                │                │          │
# │ look into      │                │ occurred after  │                │                │                │          │
# │ this?          │                │ the customer's  │                │                │                │          │
# │                │                │ last ride.      │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ My driver was  │ ['driver       │ There is no     │ No             │ Very positive  │ No             │ 0        │
# │ very           │ performance']  │ issue reported  │                │                │                │          │
# │ considerate,   │                │ in this ticket. │                │                │                │          │
# │ especially     │                │ The customer is │                │                │                │          │
# │ helping me     │                │ expressing      │                │                │                │          │
# │ with my        │                │ appreciation    │                │                │                │          │
# │ luggage.       │                │ for the         │                │                │                │          │
# │ Appreciate the │                │ considerate     │                │                │                │          │
# │ great service! │                │ service         │                │                │                │          │
# │                │                │ provided by the │                │                │                │          │
# │                │                │ driver.         │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ My driver took │ ['driver       │ The primary     │ No             │ Somewhat       │ No             │ 3        │
# │ a longer route │ performance',  │ issue in the    │                │ negative       │                │          │
# │ than           │ 'GPS/route']   │ ticket is that  │                │                │                │          │
# │ necessary,     │                │ the customer is │                │                │                │          │
# │ resulting in a │                │ reporting that  │                │                │                │          │
# │ higher fare. I │                │ the driver took │                │                │                │          │
# │ request a fare │                │ a longer route  │                │                │                │          │
# │ adjustment.    │                │ than necessary, │                │                │                │          │
# │                │                │ which led to an │                │                │                │          │
# │                │                │ increased fare. │                │                │                │          │
# │                │                │ The customer is │                │                │                │          │
# │                │                │ requesting a    │                │                │                │          │
# │                │                │ fare adjustment │                │                │                │          │
# │                │                │ due to this     │                │                │                │          │
# │                │                │ issue.          │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I just         │ ['lost item']  │ The primary     │ Not applicable │ Somewhat       │ No             │ 4        │
# │ realized I     │                │ issue in this   │                │ negative       │                │          │
# │ left my phone  │                │ ticket is that  │                │                │                │          │
# │ in the car on  │                │ the customer    │                │                │                │          │
# │ my last ride.  │                │ has left their  │                │                │                │          │
# │ Can you help   │                │ phone in the    │                │                │                │          │
# │ me get it      │                │ car on their    │                │                │                │          │
# │ back?          │                │ last ride and   │                │                │                │          │
# │                │                │ is seeking      │                │                │                │          │
# │                │                │ assistance to   │                │                │                │          │
# │                │                │ retrieve it.    │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The app's GPS  │ ['GPS/route']  │ The primary     │ No             │ Somewhat       │ No             │ 4        │
# │ seems          │                │ issue in the    │                │ negative       │                │          │
# │ inaccurate. It │                │ ticket is that  │                │                │                │          │
# │ directed the   │                │ the app's GPS   │                │                │                │          │
# │ driver to the  │                │ is providing    │                │                │                │          │
# │ wrong pick-up  │                │ inaccurate      │                │                │                │          │
# │ location.      │                │ directions,     │                │                │                │          │
# │                │                │ leading the     │                │                │                │          │
# │                │                │ driver to an    │                │                │                │          │
# │                │                │ incorrect       │                │                │                │          │
# │                │                │ pick-up         │                │                │                │          │
# │                │                │ location.       │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The driver     │ ['driver       │ The primary     │ No             │ Somewhat       │ No             │ 2        │
# │ refused to     │ performance',  │ issue in this   │                │ negative       │                │          │
# │ follow my      │ 'GPS/route']   │ ticket is that  │                │                │                │          │
# │ preferred      │                │ the driver      │                │                │                │          │
# │ route, which   │                │ refused to      │                │                │                │          │
# │ is shorter.    │                │ follow the      │                │                │                │          │
# │ I'm not        │                │ customer's      │                │                │                │          │
# │ satisfied with │                │ preferred       │                │                │                │          │
# │ the service.   │                │ route, which    │                │                │                │          │
# │                │                │ the customer    │                │                │                │          │
# │                │                │ believes is     │                │                │                │          │
# │                │                │ shorter,        │                │                │                │          │
# │                │                │ leading to      │                │                │                │          │
# │                │                │ dissatisfaction │                │                │                │          │
# │                │                │ with the        │                │                │                │          │
# │                │                │ service         │                │                │                │          │
# │                │                │ provided.       │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The app keeps  │ ['other']      │ The primary     │ No             │ Very negative  │ No             │ 4        │
# │ crashing every │                │ issue reported  │                │                │                │          │
# │ time I try to  │                │ in the ticket   │                │                │                │          │
# │ book a ride.   │                │ is that the     │                │                │                │          │
# │ Please fix     │                │ application is  │                │                │                │          │
# │ this issue.    │                │ crashing every  │                │                │                │          │
# │                │                │ time the user   │                │                │                │          │
# │                │                │ attempts to     │                │                │                │          │
# │                │                │ book a ride.    │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I had a great  │ ['driver       │ There is no     │ No             │ Very positive  │ No             │ 0        │
# │ experience     │ performance']  │ issue reported  │                │                │                │          │
# │ with my driver │                │ in this ticket. │                │                │                │          │
# │ today! Very    │                │ The customer is │                │                │                │          │
# │ friendly and   │                │ providing       │                │                │                │          │
# │ efficient      │                │ positive        │                │                │                │          │
# │ service.       │                │ feedback about  │                │                │                │          │
# │                │                │ a great         │                │                │                │          │
# │                │                │ experience with │                │                │                │          │
# │                │                │ a friendly and  │                │                │                │          │
# │                │                │ efficient       │                │                │                │          │
# │                │                │ driver.         │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I'm concerned  │ ['cleanliness… │ The primary     │ No             │ Somewhat       │ No             │ 3        │
# │ about the      │                │ issue in the    │                │ negative       │                │          │
# │ vehicle's      │                │ ticket is the   │                │                │                │          │
# │ cleanliness.   │                │ customer's      │                │                │                │          │
# │ It was not up  │                │ concern         │                │                │                │          │
# │ to the         │                │ regarding the   │                │                │                │          │
# │ standard I     │                │ cleanliness of  │                │                │                │          │
# │ expect.        │                │ the vehicle,    │                │                │                │          │
# │                │                │ which did not   │                │                │                │          │
# │                │                │ meet their      │                │                │                │          │
# │                │                │ expected        │                │                │                │          │
# │                │                │ standard.       │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I felt unsafe  │ ['safety',     │ The primary     │ No             │ Very negative  │ No             │ 5        │
# │ during my ride │ 'driver        │ issue in the    │                │                │                │          │
# │ due to the     │ performance']  │ ticket is that  │                │                │                │          │
# │ driver's       │                │ the customer    │                │                │                │          │
# │ erratic        │                │ felt unsafe due │                │                │                │          │
# │ behavior. This │                │ to the driver's │                │                │                │          │
# │ needs to be    │                │ erratic         │                │                │                │          │
# │ addressed      │                │ behavior and is │                │                │                │          │
# │ immediately.   │                │ requesting      │                │                │                │          │
# │                │                │ immediate       │                │                │                │          │
# │                │                │ action to       │                │                │                │          │
# │                │                │ address this    │                │                │                │          │
# │                │                │ concern.        │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ My driver was  │ ['safety',     │ The primary     │ No             │ Very positive  │ No             │ 0        │
# │ exceptional -  │ 'cleanliness', │ issue in this   │                │                │                │          │
# │ safe driving,  │ 'driver        │ ticket is not a │                │                │                │          │
# │ polite, and    │ performance']  │ problem but     │                │                │                │          │
# │ the car was    │                │ positive        │                │                │                │          │
# │ spotless.      │                │ feedback        │                │                │                │          │
# │ Kudos!         │                │ regarding the   │                │                │                │          │
# │                │                │ driver's        │                │                │                │          │
# │                │                │ performance.    │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The promo code │ ['other']      │ The primary     │ No             │ Somewhat       │ No             │ 3        │
# │ I tried to use │                │ issue in this   │                │ negative       │                │          │
# │ didn't work.   │                │ ticket is that  │                │                │                │          │
# │ Can you assist │                │ the customer    │                │                │                │          │
# │ with this?     │                │ attempted to    │                │                │                │          │
# │                │                │ use a promo     │                │                │                │          │
# │                │                │ code which did  │                │                │                │          │
# │                │                │ not work, and   │                │                │                │          │
# │                │                │ they are        │                │                │                │          │
# │                │                │ requesting      │                │                │                │          │
# │                │                │ assistance to   │                │                │                │          │
# │                │                │ resolve the     │                │                │                │          │
# │                │                │ issue.          │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I was charged  │ ['other']      │ The primary     │ Not applicable │ Somewhat       │ No             │ 3        │
# │ more than the  │                │ issue in this   │                │ negative       │                │          │
# │ estimated fare │                │ ticket is that  │                │                │                │          │
# │ for my trip    │                │ the customer    │                │                │                │          │
# │ yesterday. Can │                │ was charged an  │                │                │                │          │
# │ you explain    │                │ amount          │                │                │                │          │
# │ why?           │                │ exceeding the   │                │                │                │          │
# │                │                │ estimated fare  │                │                │                │          │
# │                │                │ for their trip  │                │                │                │          │
# │                │                │ and is seeking  │                │                │                │          │
# │                │                │ an explanation  │                │                │                │          │
# │                │                │ for the         │                │                │                │          │
# │                │                │ discrepancy.    │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The vehicle    │ ['other']      │ The primary     │ No             │ Somewhat       │ No             │ 4        │
# │ didn't match   │                │ issue in the    │                │ negative       │                │          │
# │ the            │                │ ticket is that  │                │                │                │          │
# │ description in │                │ the vehicle     │                │                │                │          │
# │ the app. It    │                │ that arrived    │                │                │                │          │
# │ was confusing  │                │ did not match   │                │                │                │          │
# │ and            │                │ the description │                │                │                │          │
# │ concerning.    │                │ provided in the │                │                │                │          │
# │                │                │ app, which      │                │                │                │          │
# │                │                │ caused          │                │                │                │          │
# │                │                │ confusion and   │                │                │                │          │
# │                │                │ concern for the │                │                │                │          │
# │                │                │ customer.       │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ There was a    │ ['cleanliness… │ The primary     │ No             │ Somewhat       │ No             │ 3        │
# │ suspicious     │                │ issue in the    │                │ negative       │                │          │
# │ smell in the   │                │ ticket is a     │                │                │                │          │
# │ car, and I'm   │                │ concern         │                │                │                │          │
# │ worried about  │                │ regarding a     │                │                │                │          │
# │ hygiene        │                │ suspicious      │                │                │                │          │
# │ standards.     │                │ smell in the    │                │                │                │          │
# │                │                │ car, which has  │                │                │                │          │
# │                │                │ raised worries  │                │                │                │          │
# │                │                │ about the       │                │                │                │          │
# │                │                │ vehicle's       │                │                │                │          │
# │                │                │ hygiene         │                │                │                │          │
# │                │                │ standards.      │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I was charged  │ ['other']      │ The primary     │ Not applicable │ Somewhat       │ Yes            │ 4        │
# │ for a ride I   │                │ issue in the    │                │ negative       │                │          │
# │ never took.    │                │ ticket is that  │                │                │                │          │
# │ Please refund  │                │ the customer    │                │                │                │          │
# │ me as soon as  │                │ has been        │                │                │                │          │
# │ possible.      │                │ charged for a   │                │                │                │          │
# │                │                │ ride they did   │                │                │                │          │
# │                │                │ not take and is │                │                │                │          │
# │                │                │ requesting a    │                │                │                │          │
# │                │                │ prompt refund.  │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ The car seat   │ ['safety',     │ The primary     │ No             │ Very negative  │ No             │ 5        │
# │ provided was   │ 'driver        │ issue in this   │                │                │                │          │
# │ not properly   │ performance']  │ ticket is that  │                │                │                │          │
# │ installed, and │                │ the car seat    │                │                │                │          │
# │ I felt my      │                │ provided was    │                │                │                │          │
# │ child was at   │                │ not properly    │                │                │                │          │
# │ risk. Please   │                │ installed,      │                │                │                │          │
# │ ensure driver  │                │ which led to    │                │                │                │          │
# │ training.      │                │ concerns about  │                │                │                │          │
# │                │                │ the child's     │                │                │                │          │
# │                │                │ safety. The     │                │                │                │          │
# │                │                │ customer is     │                │                │                │          │
# │                │                │ requesting      │                │                │                │          │
# │                │                │ improved driver │                │                │                │          │
# │                │                │ training to     │                │                │                │          │
# │                │                │ ensure proper   │                │                │                │          │
# │                │                │ installation of │                │                │                │          │
# │                │                │ car seats in    │                │                │                │          │
# │                │                │ the future.     │                │                │                │          │
# ├────────────────┼────────────────┼─────────────────┼────────────────┼────────────────┼────────────────┼──────────┤
# │ I'm unhappy    │ ['driver       │ The primary     │ No             │ Very negative  │ No             │ 4        │
# │ with my recent │ performance']  │ issue in this   │                │                │                │          │
# │ experience.    │                │ ticket is that  │                │                │                │          │
# │ The driver was │                │ the customer    │                │                │                │          │
# │ very rude and  │                │ experienced     │                │                │                │          │
# │ unprofessiona… │                │ rude and        │                │                │                │          │
# │                │                │ unprofessional  │                │                │                │          │
# │                │                │ behavior from a │                │                │                │          │
# │                │                │ driver.         │                │                │                │          │
# └────────────────┴────────────────┴─────────────────┴────────────────┴────────────────┴────────────────┴──────────┘

# %% [markdown]
# We can explore some built-in visualization methods:

# %%
results.bar_chart("accident")
# Out:
# If the primary issue in this ticket is safety, was there an accident where someone was hurt? Ticket: {{ticket}}
# <img src="data:image/svg+xml;base64,..." style="width: 100%; height: auto;"  />
# <p>Codes:</p>
# <p><b>yes</b>: Yes</p>
# <p><b>no</b>: No</p>
# <p><b>not</b>: Not applicable</p>

# %%
results.bar_chart("sentiment")
# Out:
# What is the sentiment of this ticket? Ticket: {{ticket}}
# <img src="data:image/svg+xml;base64,..." style="width: 100%; height: auto;"  />
# <p>Codes:</p>
# <p><b>very</b>: Very positive</p>
# <p><b>somewhat</b>: Somewhat positive</p>
# <p><b>neutral</b>: Neutral</p>
# <p><b>somewhat_negative</b>: Somewhat negative</p>
# <p><b>very_negative</b>: Very negative</p>

# %%
results.bar_chart("refund")
# Out:
# Does the customer ask for a refund in this ticket? Ticket: {{ticket}}
# <img src="data:image/svg+xml;base64,..." style="width: 100%; height: auto;"  />

# %%
results.bar_chart("priority")
# Out:
# On a scale from 0 (lowest) to 5 (highest), what is the priority level of this ticket? Ticket: {{ticket}}
# <img src="data:image/svg+xml;base64,..." style="width: 100%; height: auto;"  />

# %%
results.tally("sentiment")
# Out:
# <div>
# <p>What is the sentiment of this ticket? Ticket: {{ticket}}</p><table>
# <tr><td>Very negative</td><td>4</td></tr>
# <tr><td>Somewhat negative</td><td>11</td></tr>
# <tr><td>Neutral</td><td>0</td></tr>
# <tr><td>Somewhat positive</td><td>0</td></tr>
# <tr><td>Very positive</td><td>5</td></tr>
# </table>
# </div>

# %%
results.tally("priority")
# Out:
# <div>
# <p>On a scale from 0 (lowest) to 5 (highest), what is the priority level of this ticket? Ticket: {{ticket}}</p><table>
# <tr><td>5</td><td>2</td></tr>
# <tr><td>4</td><td>7</td></tr>
# <tr><td>3</td><td>5</td></tr>
# <tr><td>2</td><td>1</td></tr>
# <tr><td>1</td><td>0</td></tr>
# <tr><td>0</td><td>5</td></tr>
# </table>
# </div>

# %%
results.word_cloud_plot("issues")
# Out:
# <img src="data:image/svg+xml;base64,..." style="width: 100%; height: auto;"  />

# %% [markdown]
# ---
# <p style="font-size: 14px;">Copyright © 2024 Expected Parrot, Inc. All rights reserved.   <a href="www.expectedparrot.com" style="color:#130061">www.expectedparrot.com</a></p>
