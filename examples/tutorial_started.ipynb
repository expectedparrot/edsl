# %% [markdown]
# # Starter Tutorial
# This page provides a guide for getting started running your first AI-powered research!

# %% [markdown]
# <i>The <a href="https://docs.expectedparrot.com" target="_blank" class="text-blue-500 hover:text-blue-600">EDSL Docs<i class="fa fa-mail-forward"></i></a> also provide installation instructions, starter tutorials, and in-depth documentation for the components of the EDSL library.</i>

# %%
# ! pip install edsl

# %% [markdown]
# ## Part 1: Using API Keys
#
# Large language models (LLMs) are at the heart of AI-powered research. EDSL allows you to easily conduct research with popular LLMs, including OpenAI's GPTs, Google's Gemini, Anthropic's Claude, Llama 2 and others. In order to do so, you must provide EDSL with your API keys from LLM providers. <i>EDSL will never store your personal API keys.</i>
#
# There are 2 ways to provide your API keys to EDSL:
#
# ### 1. Recommended: Use a .env file
#
# Create a file with the name `.env` in your working directory and populate it as follows, replacing `your_key_here` with your actual API keys:
#
# ```
#    ANTHROPIC_API_KEY=your_key_here
#    DEEP_INFRA_API_KEY=your_key_here
#    GOOGLE_API_KEY=your_key_here
#    OPENAI_API_KEY=your_key_here
# ```
#
# EDSL will read your API keys from this file. This method allows you to avoid having to provide your keys each time that you start a session with EDSL and is the recommended way to provide your API keys.
#
# If you are not planning to use one of these providers you can comment out the line.
# This will ensure that you get an error message if you accidentally try to use that provider without a valid API key. For example, if you only plan to use models provided by Anthropic, you can set your `.env` file as follows:
#
# ```
#    ANTHROPIC_API_KEY=your_key_here
#    # DEEP_INFRA_API_KEY=your_key_here
#    # GOOGLE_API_KEY=your_key_here
#    # OPENAI_API_KEY=your_key_here
# ```
#
# ### 2. Set your API keys in your Python code
#
# You can alternatively set your API keys in your Python code before you import any EDSL object as follows:
#
# ```
#    import os
#    os.environ['ANTHROPIC_API_KEY'] = 'your_key_here'
#    os.environ['DEEP_INFRA_API_KEY'] = 'your_key_here'
#    os.environ['GOOGLE_API_KEY'] = 'your_key_here'
#    os.environ['OPENAI_API_KEY'] = 'your_key_here'
# ```
#
# Note that EDSL will store your API keys in your system's memory only for the duration of your session. If you restart your session, you will need to set your API keys again.
#
# If you are not planning to use one of these providers you can delete the line. This will ensure that you get an error message if you accidentally try to use that provider without a valid API key.
#
# ### Caution
#
# You should always treat your API keys like you treat your passwords: never share them or upload files with your API keys to any public repository.

# %% [markdown]
# ## Part 2: Conducting AI-powered research
# With your API keys in place, you're now ready for AI-powered research! In this part we show how to create and run a simple survey in just a couple lines of code, and then create a proper survey with only slightly more work.

# %% [markdown]
# ### Quickstart Example
# Here we create a multiple choice question, prompt an AI agent answer it, and inspect the results:

# %%
# Import a desired question type
from edsl.questions import QuestionMultipleChoice

# Construct a question
q = QuestionMultipleChoice(
    question_name = "example_question",
    question_text = "How do you feel today?",
    question_options = ["Bad", "OK", "Good"]
)

# Prompt the default model to answer it (GPT-4)
results = q.run()

# Inspect the results
results.select("example_question").print()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━┓
# ┃ answer            ┃
# ┃ .example_question ┃
# ┡━━━━━━━━━━━━━━━━━━━┩
# │ Good              │
# └───────────────────┘

# %% [markdown]
# ### A Proper Survey
# Here we create a more complex survey where we ask AI agents how much they enjoy different activities. We also create agents with different personas, and use different LLMs to generate the results:

# %%
from edsl.questions import QuestionLinearScale, QuestionFreeText
from edsl import Scenario, Survey, Agent, Model

# Construct questions 
# Note that we use a parameter `activity` in order to create multiple scenarios of the question texts
q1 = QuestionLinearScale(
    question_name = "q1",
    question_text = "On a scale from 0 to 5, how much do you enjoy {{ activity }}?",
    question_options = [0,1,2,3,4,5]
)

q2 = QuestionFreeText(
    question_name = "q2",
    question_text = "Describe your habits with respect to {{ activity }}."
)

# Scenarios let us construct multiple variations of the same questions
activities = ["exercising", "reading", "cooking"]
scenarios = [Scenario({"activity": a}) for a in activities]

# Combine the questions in a survey
survey = Survey(questions = [q1, q2])

# Create personas for agents that will respond to the survey
personas = ["You are an athlete", "You are a student", "You are a chef"]
agents = [Agent(traits = {"persona": p}) for p in personas]

# Select language models
models = [Model("gpt-3.5-turbo"), Model("gpt-4-1106-preview")]

# Administer the survey 
results = survey.by(scenarios).by(agents).by(models).run()

# View the results
results.select("model.model", "scenario.activity", "agent.persona", "answer.*").print()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ model              ┃ scenario   ┃ agent              ┃ answer                 ┃ answer                 ┃ answer ┃
# ┃ .model             ┃ .activity  ┃ .persona           ┃ .q2                    ┃ .q1_comment            ┃ .q1    ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ gpt-3.5-turbo      │ exercising │ You are a student  │ I try to exercise at   │ I enjoy exercising     │ 3      │
# │                    │            │                    │ least three times a    │ moderately, it helps   │        │
# │                    │            │                    │ week, usually going    │ me stay healthy and    │        │
# │                    │            │                    │ for a run or doing a   │ relieve stress.        │        │
# │                    │            │                    │ workout at the gym. I  │                        │        │
# │                    │            │                    │ find that it helps me  │                        │        │
# │                    │            │                    │ stay energized and     │                        │        │
# │                    │            │                    │ focused throughout the │                        │        │
# │                    │            │                    │ day.                   │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ exercising │ You are a chef     │ As a chef, my job      │ As a chef, I enjoy     │ 1      │
# │                    │            │                    │ keeps me on my feet    │ cooking and creating   │        │
# │                    │            │                    │ for long hours in the  │ delicious dishes more  │        │
# │                    │            │                    │ kitchen, so I consider │ than exercising.       │        │
# │                    │            │                    │ that my exercise. I    │                        │        │
# │                    │            │                    │ also enjoy going for   │                        │        │
# │                    │            │                    │ walks or bike rides on │                        │        │
# │                    │            │                    │ my days off to stay    │                        │        │
# │                    │            │                    │ active and clear my    │                        │        │
# │                    │            │                    │ mind.                  │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ cooking    │ You are a student  │ I enjoy cooking and    │ I enjoy cooking a      │ 2      │
# │                    │            │                    │ like to experiment     │ moderate amount, it's  │        │
# │                    │            │                    │ with new recipes. I    │ a fun way to relax and │        │
# │                    │            │                    │ usually cook simple    │ be creative in the     │        │
# │                    │            │                    │ meals during the week  │ kitchen.               │        │
# │                    │            │                    │ and try more elaborate │                        │        │
# │                    │            │                    │ dishes on weekends     │                        │        │
# │                    │            │                    │ when I have more time. │                        │        │
# │                    │            │                    │ Cooking is a way for   │                        │        │
# │                    │            │                    │ me to relax and unwind │                        │        │
# │                    │            │                    │ after a long day of    │                        │        │
# │                    │            │                    │ studying.              │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ exercising │ You are an athlete │ I exercise regularly   │ I enjoy exercising a   │ 5      │
# │                    │            │                    │ to maintain my fitness │ lot. It helps me stay  │        │
# │                    │            │                    │ level and improve my   │ fit, focused, and      │        │
# │                    │            │                    │ performance in my      │ energized for my       │        │
# │                    │            │                    │ sport. I follow a      │ athletic pursuits.     │        │
# │                    │            │                    │ structured training    │                        │        │
# │                    │            │                    │ program that includes  │                        │        │
# │                    │            │                    │ a mix of cardio,       │                        │        │
# │                    │            │                    │ strength training, and │                        │        │
# │                    │            │                    │ flexibility exercises. │                        │        │
# │                    │            │                    │ I also make sure to    │                        │        │
# │                    │            │                    │ listen to my body and  │                        │        │
# │                    │            │                    │ give it the rest it    │                        │        │
# │                    │            │                    │ needs to recover       │                        │        │
# │                    │            │                    │ properly.              │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ cooking    │ You are a chef     │ As a chef, I have      │ I absolutely love      │ 5      │
# │                    │            │                    │ developed a routine of │ cooking. It's my       │        │
# │                    │            │                    │ planning my meals in   │ passion and brings me  │        │
# │                    │            │                    │ advance, preparing all │ joy every day.         │        │
# │                    │            │                    │ the necessary          │                        │        │
# │                    │            │                    │ ingredients before     │                        │        │
# │                    │            │                    │ starting to cook, and  │                        │        │
# │                    │            │                    │ keeping my kitchen     │                        │        │
# │                    │            │                    │ organized and clean. I │                        │        │
# │                    │            │                    │ also enjoy             │                        │        │
# │                    │            │                    │ experimenting with new │                        │        │
# │                    │            │                    │ recipes and            │                        │        │
# │                    │            │                    │ ingredients to         │                        │        │
# │                    │            │                    │ constantly improve my  │                        │        │
# │                    │            │                    │ cooking skills.        │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ reading    │ You are a chef     │ As a chef, I enjoy     │ I enjoy reading a lot, │ 5      │
# │                    │            │                    │ reading cookbooks,     │ it allows me to        │        │
# │                    │            │                    │ food magazines, and    │ discover new recipes   │        │
# │                    │            │                    │ online culinary        │ and techniques to      │        │
# │                    │            │                    │ articles to stay       │ improve my cooking     │        │
# │                    │            │                    │ updated on the latest  │ skills.                │        │
# │                    │            │                    │ trends, techniques,    │                        │        │
# │                    │            │                    │ and recipes in the     │                        │        │
# │                    │            │                    │ culinary world. I also │                        │        │
# │                    │            │                    │ find inspiration in    │                        │        │
# │                    │            │                    │ reading about          │                        │        │
# │                    │            │                    │ different cuisines and │                        │        │
# │                    │            │                    │ food cultures from     │                        │        │
# │                    │            │                    │ around the globe.      │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ reading    │ You are a student  │ I try to read for at   │ I really enjoy         │ 4      │
# │                    │            │                    │ least 30 minutes every │ reading, it helps me   │        │
# │                    │            │                    │ day, usually before    │ relax and learn new    │        │
# │                    │            │                    │ going to bed. I enjoy  │ things.                │        │
# │                    │            │                    │ reading a variety of   │                        │        │
# │                    │            │                    │ genres, from fiction   │                        │        │
# │                    │            │                    │ to self-help books.    │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ reading    │ You are an athlete │ As an athlete, I       │ I enjoy reading a      │ 1      │
# │                    │            │                    │ prioritize reading     │ little bit, so I'll    │        │
# │                    │            │                    │ materials related to   │ choose option 1.       │        │
# │                    │            │                    │ sports science,        │                        │        │
# │                    │            │                    │ fitness, and mental    │                        │        │
# │                    │            │                    │ toughness. I usually   │                        │        │
# │                    │            │                    │ read before bed to     │                        │        │
# │                    │            │                    │ relax and unwind, and  │                        │        │
# │                    │            │                    │ also during travel     │                        │        │
# │                    │            │                    │ times to competitions  │                        │        │
# │                    │            │                    │ or training sessions.  │                        │        │
# │                    │            │                    │ Reading helps me stay  │                        │        │
# │                    │            │                    │ motivated, learn new   │                        │        │
# │                    │            │                    │ training techniques,   │                        │        │
# │                    │            │                    │ and gain insights into │                        │        │
# │                    │            │                    │ the mental aspect of   │                        │        │
# │                    │            │                    │ sports performance.    │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-3.5-turbo      │ cooking    │ You are an athlete │ As an athlete, I       │ I enjoy cooking a      │ 1      │
# │                    │            │                    │ prioritize healthy     │ little bit, but it's   │        │
# │                    │            │                    │ eating and proper      │ not my favorite        │        │
# │                    │            │                    │ nutrition to support   │ activity               │        │
# │                    │            │                    │ my training and        │                        │        │
# │                    │            │                    │ performance. I usually │                        │        │
# │                    │            │                    │ meal prep in advance   │                        │        │
# │                    │            │                    │ to ensure I have       │                        │        │
# │                    │            │                    │ balanced meals ready   │                        │        │
# │                    │            │                    │ to go. I focus on      │                        │        │
# │                    │            │                    │ incorporating lean     │                        │        │
# │                    │            │                    │ proteins, whole        │                        │        │
# │                    │            │                    │ grains, fruits, and    │                        │        │
# │                    │            │                    │ vegetables into my     │                        │        │
# │                    │            │                    │ diet. Cooking is a way │                        │        │
# │                    │            │                    │ for me to control what │                        │        │
# │                    │            │                    │ I eat and make sure I  │                        │        │
# │                    │            │                    │ am fueling my body     │                        │        │
# │                    │            │                    │ effectively.           │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ exercising │ You are a student  │ I usually exercise     │ I really enjoy         │ 4      │
# │                    │            │                    │ about four to five     │ exercising as it helps │        │
# │                    │            │                    │ times a week. My       │ me to stay fit and     │        │
# │                    │            │                    │ routine typically      │ feel energized, but    │        │
# │                    │            │                    │ includes a mix of      │ there are times when   │        │
# │                    │            │                    │ cardiovascular         │ it can be a bit of a   │        │
# │                    │            │                    │ activities like        │ chore.                 │        │
# │                    │            │                    │ running or cycling and │                        │        │
# │                    │            │                    │ strength training with │                        │        │
# │                    │            │                    │ weights. I also enjoy  │                        │        │
# │                    │            │                    │ yoga for flexibility   │                        │        │
# │                    │            │                    │ and balance. I try to  │                        │        │
# │                    │            │                    │ keep my workouts       │                        │        │
# │                    │            │                    │ varied to stay         │                        │        │
# │                    │            │                    │ motivated and cover    │                        │        │
# │                    │            │                    │ different aspects of   │                        │        │
# │                    │            │                    │ fitness.               │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ reading    │ You are a chef     │ As a chef, my reading  │ I really enjoy         │ 4      │
# │                    │            │                    │ habits are largely     │ reading, especially    │        │
# │                    │            │                    │ centered around        │ when it comes to       │        │
# │                    │            │                    │ cookbooks, culinary    │ cookbooks and culinary │        │
# │                    │            │                    │ magazines, and         │ literature to expand   │        │
# │                    │            │                    │ food-related articles. │ my knowledge and       │        │
# │                    │            │                    │ I enjoy staying        │ skills in the kitchen. │        │
# │                    │            │                    │ updated on the latest  │                        │        │
# │                    │            │                    │ food trends,           │                        │        │
# │                    │            │                    │ techniques, and        │                        │        │
# │                    │            │                    │ recipes. I also make   │                        │        │
# │                    │            │                    │ it a point to read     │                        │        │
# │                    │            │                    │ about different        │                        │        │
# │                    │            │                    │ cuisines and cultures  │                        │        │
# │                    │            │                    │ to inspire my cooking. │                        │        │
# │                    │            │                    │ When I find time       │                        │        │
# │                    │            │                    │ outside the kitchen, I │                        │        │
# │                    │            │                    │ like to unwind with a  │                        │        │
# │                    │            │                    │ good novel or a        │                        │        │
# │                    │            │                    │ biography, especially  │                        │        │
# │                    │            │                    │ if it's related to the │                        │        │
# │                    │            │                    │ culinary world.        │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ exercising │ You are a chef     │ As a chef, my schedule │ I enjoy exercising to  │ 3      │
# │                    │            │                    │ can be quite hectic,   │ a moderate extent.     │        │
# │                    │            │                    │ but I try to maintain  │ It's important for     │        │
# │                    │            │                    │ a regular exercise     │ maintaining health,    │        │
# │                    │            │                    │ routine to keep up     │ especially with a      │        │
# │                    │            │                    │ with the physical      │ physically demanding   │        │
# │                    │            │                    │ demands of the         │ job like cooking.      │        │
# │                    │            │                    │ kitchen. I usually     │                        │        │
# │                    │            │                    │ exercise early in the  │                        │        │
# │                    │            │                    │ morning before my      │                        │        │
# │                    │            │                    │ shift starts, focusing │                        │        │
# │                    │            │                    │ on a mix of cardio and │                        │        │
# │                    │            │                    │ strength training to   │                        │        │
# │                    │            │                    │ help with endurance    │                        │        │
# │                    │            │                    │ and lifting heavy pots │                        │        │
# │                    │            │                    │ and pans. On my days   │                        │        │
# │                    │            │                    │ off, I enjoy taking a  │                        │        │
# │                    │            │                    │ long walk or hike to   │                        │        │
# │                    │            │                    │ clear my mind and get  │                        │        │
# │                    │            │                    │ some fresh air.        │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ cooking    │ You are an athlete │ As an athlete, my      │ I enjoy cooking to a   │ 3      │
# │                    │            │                    │ cooking habits are     │ moderate extent. It's  │        │
# │                    │            │                    │ largely focused on     │ a good skill for       │        │
# │                    │            │                    │ preparing nutritious   │ maintaining a healthy  │        │
# │                    │            │                    │ meals that support my  │ diet, which is         │        │
# │                    │            │                    │ training and recovery. │ important for my       │        │
# │                    │            │                    │ I prioritize           │ athletic performance.  │        │
# │                    │            │                    │ high-quality proteins, │                        │        │
# │                    │            │                    │ complex carbohydrates, │                        │        │
# │                    │            │                    │ and plenty of fruits   │                        │        │
# │                    │            │                    │ and vegetables. I      │                        │        │
# │                    │            │                    │ often meal prep at the │                        │        │
# │                    │            │                    │ beginning of the week  │                        │        │
# │                    │            │                    │ to ensure I have       │                        │        │
# │                    │            │                    │ healthy options        │                        │        │
# │                    │            │                    │ readily available, and │                        │        │
# │                    │            │                    │ I enjoy experimenting  │                        │        │
# │                    │            │                    │ with different recipes │                        │        │
# │                    │            │                    │ that align with my     │                        │        │
# │                    │            │                    │ dietary needs. Cooking │                        │        │
# │                    │            │                    │ at home allows me to   │                        │        │
# │                    │            │                    │ control the            │                        │        │
# │                    │            │                    │ ingredients and        │                        │        │
# │                    │            │                    │ portion sizes, which   │                        │        │
# │                    │            │                    │ is crucial for         │                        │        │
# │                    │            │                    │ maintaining my         │                        │        │
# │                    │            │                    │ athletic performance.  │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ reading    │ You are a student  │ I have a pretty        │ I really enjoy         │ 5      │
# │                    │            │                    │ consistent reading     │ reading; it's a great  │        │
# │                    │            │                    │ habit. I usually set   │ way to learn and       │        │
# │                    │            │                    │ aside at least 30      │ escape into different  │        │
# │                    │            │                    │ minutes each night     │ worlds.                │        │
# │                    │            │                    │ before bed to read     │                        │        │
# │                    │            │                    │ something. I prefer    │                        │        │
# │                    │            │                    │ physical books over    │                        │        │
# │                    │            │                    │ digital ones because I │                        │        │
# │                    │            │                    │ enjoy the tactile      │                        │        │
# │                    │            │                    │ sensation of turning   │                        │        │
# │                    │            │                    │ pages and I find it    │                        │        │
# │                    │            │                    │ easier on my eyes. I   │                        │        │
# │                    │            │                    │ like to mix up the     │                        │        │
# │                    │            │                    │ genres I read,         │                        │        │
# │                    │            │                    │ alternating between    │                        │        │
# │                    │            │                    │ fiction, non-fiction,  │                        │        │
# │                    │            │                    │ and academic texts     │                        │        │
# │                    │            │                    │ related to my studies. │                        │        │
# │                    │            │                    │ I also make it a point │                        │        │
# │                    │            │                    │ to visit the library   │                        │        │
# │                    │            │                    │ every two weeks to     │                        │        │
# │                    │            │                    │ find new titles and    │                        │        │
# │                    │            │                    │ attend any interesting │                        │        │
# │                    │            │                    │ talks or book clubs    │                        │        │
# │                    │            │                    │ they might be hosting. │                        │        │
# │                    │            │                    │ Additionally, I keep a │                        │        │
# │                    │            │                    │ reading log to track   │                        │        │
# │                    │            │                    │ my thoughts on the     │                        │        │
# │                    │            │                    │ books I've completed.  │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ cooking    │ You are a student  │ I usually cook at home │ I really enjoy cooking │ 4      │
# │                    │            │                    │ a few times a week,    │ as it's a relaxing and │        │
# │                    │            │                    │ often preparing meals  │ creative process for   │        │
# │                    │            │                    │ in advance to save     │ me.                    │        │
# │                    │            │                    │ time. I like to        │                        │        │
# │                    │            │                    │ experiment with        │                        │        │
# │                    │            │                    │ different recipes and  │                        │        │
# │                    │            │                    │ cuisines, but I also   │                        │        │
# │                    │            │                    │ have a few go-to       │                        │        │
# │                    │            │                    │ dishes that are quick  │                        │        │
# │                    │            │                    │ and easy when I'm busy │                        │        │
# │                    │            │                    │ with studies. I try to │                        │        │
# │                    │            │                    │ balance healthy eating │                        │        │
# │                    │            │                    │ with the occasional    │                        │        │
# │                    │            │                    │ indulgence and enjoy   │                        │        │
# │                    │            │                    │ using fresh            │                        │        │
# │                    │            │                    │ ingredients whenever   │                        │        │
# │                    │            │                    │ possible.              │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ exercising │ You are an athlete │ My exercise routine is │ I absolutely love      │ 5      │
# │                    │            │                    │ quite structured and   │ exercising; it's a     │        │
# │                    │            │                    │ consistent, as         │ crucial part of my     │        │
# │                    │            │                    │ maintaining peak       │ life as an athlete.    │        │
# │                    │            │                    │ physical fitness is    │                        │        │
# │                    │            │                    │ crucial for my         │                        │        │
# │                    │            │                    │ athletic performance.  │                        │        │
# │                    │            │                    │ I typically work out   │                        │        │
# │                    │            │                    │ five to six days a     │                        │        │
# │                    │            │                    │ week, incorporating a  │                        │        │
# │                    │            │                    │ mix of strength        │                        │        │
# │                    │            │                    │ training,              │                        │        │
# │                    │            │                    │ cardiovascular         │                        │        │
# │                    │            │                    │ exercises, and         │                        │        │
# │                    │            │                    │ sport-specific drills. │                        │        │
# │                    │            │                    │ I focus on different   │                        │        │
# │                    │            │                    │ muscle groups each day │                        │        │
# │                    │            │                    │ to ensure full-body    │                        │        │
# │                    │            │                    │ development and        │                        │        │
# │                    │            │                    │ prevent overuse        │                        │        │
# │                    │            │                    │ injuries. Recovery is  │                        │        │
# │                    │            │                    │ also a key part of my  │                        │        │
# │                    │            │                    │ regimen, so I include  │                        │        │
# │                    │            │                    │ active recovery days   │                        │        │
# │                    │            │                    │ with lighter           │                        │        │
# │                    │            │                    │ activities like yoga   │                        │        │
# │                    │            │                    │ or swimming, and I     │                        │        │
# │                    │            │                    │ make sure to get       │                        │        │
# │                    │            │                    │ adequate rest and      │                        │        │
# │                    │            │                    │ sleep. Nutrition plays │                        │        │
# │                    │            │                    │ a big role as well, so │                        │        │
# │                    │            │                    │ I adhere to a balanced │                        │        │
# │                    │            │                    │ diet that supports my  │                        │        │
# │                    │            │                    │ training needs.        │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ reading    │ You are an athlete │ As an athlete, I have  │ I really enjoy reading │ 4      │
# │                    │            │                    │ a pretty busy schedule │ as it helps me relax   │        │
# │                    │            │                    │ filled with training   │ and learn new things,  │        │
# │                    │            │                    │ sessions, workouts,    │ although training and  │        │
# │                    │            │                    │ and competitions, but  │ competitions sometimes │        │
# │                    │            │                    │ I do make time for     │ limit my reading time. │        │
# │                    │            │                    │ reading as it's a      │                        │        │
# │                    │            │                    │ great way to relax and │                        │        │
# │                    │            │                    │ keep my mind sharp. I  │                        │        │
# │                    │            │                    │ tend to read in the    │                        │        │
# │                    │            │                    │ evenings to unwind     │                        │        │
# │                    │            │                    │ after a long day. My   │                        │        │
# │                    │            │                    │ reading habits include │                        │        │
# │                    │            │                    │ a mix of sports        │                        │        │
# │                    │            │                    │ biographies,           │                        │        │
# │                    │            │                    │ motivational books,    │                        │        │
# │                    │            │                    │ and occasionally       │                        │        │
# │                    │            │                    │ fiction to escape into │                        │        │
# │                    │            │                    │ different worlds. I    │                        │        │
# │                    │            │                    │ also read a lot of     │                        │        │
# │                    │            │                    │ articles and research  │                        │        │
# │                    │            │                    │ on sports science and  │                        │        │
# │                    │            │                    │ nutrition to stay      │                        │        │
# │                    │            │                    │ informed and improve   │                        │        │
# │                    │            │                    │ my performance.        │                        │        │
# ├────────────────────┼────────────┼────────────────────┼────────────────────────┼────────────────────────┼────────┤
# │ gpt-4-1106-preview │ cooking    │ You are a chef     │ As a chef, I maintain  │ As a chef, cooking is  │ 5      │
# │                    │            │                    │ a series of habits     │ my passion and I       │        │
# │                    │            │                    │ that ensure both the   │ absolutely love it.    │        │
# │                    │            │                    │ quality of the food I  │                        │        │
# │                    │            │                    │ prepare and the        │                        │        │
# │                    │            │                    │ efficiency of my       │                        │        │
# │                    │            │                    │ cooking process. I     │                        │        │
# │                    │            │                    │ start by planning my   │                        │        │
# │                    │            │                    │ menus in advance,      │                        │        │
# │                    │            │                    │ considering the        │                        │        │
# │                    │            │                    │ balance of nutrition,  │                        │        │
# │                    │            │                    │ color, and variety. I  │                        │        │
# │                    │            │                    │ source fresh,          │                        │        │
# │                    │            │                    │ high-quality           │                        │        │
# │                    │            │                    │ ingredients, often     │                        │        │
# │                    │            │                    │ from local producers,  │                        │        │
# │                    │            │                    │ to ensure the best     │                        │        │
# │                    │            │                    │ flavors. Mise en place │                        │        │
# │                    │            │                    │ is a crucial part of   │                        │        │
# │                    │            │                    │ my routine; I always   │                        │        │
# │                    │            │                    │ have all my            │                        │        │
# │                    │            │                    │ ingredients prepped    │                        │        │
# │                    │            │                    │ and ready to go before │                        │        │
# │                    │            │                    │ I start cooking.       │                        │        │
# │                    │            │                    │ Cleanliness is         │                        │        │
# │                    │            │                    │ paramount, so I clean  │                        │        │
# │                    │            │                    │ as I go to keep my     │                        │        │
# │                    │            │                    │ workspace orderly and  │                        │        │
# │                    │            │                    │ sanitary. I taste      │                        │        │
# │                    │            │                    │ frequently to adjust   │                        │        │
# │                    │            │                    │ seasoning and flavors, │                        │        │
# │                    │            │                    │ and I'm diligent about │                        │        │
# │                    │            │                    │ temperature control    │                        │        │
# │                    │            │                    │ for both cooking and   │                        │        │
# │                    │            │                    │ storing food. I also   │                        │        │
# │                    │            │                    │ make a habit of        │                        │        │
# │                    │            │                    │ experimenting with new │                        │        │
# │                    │            │                    │ techniques and flavors │                        │        │
# │                    │            │                    │ to keep my dishes      │                        │        │
# │                    │            │                    │ innovative and         │                        │        │
# │                    │            │                    │ exciting. Lastly, I    │                        │        │
# │                    │            │                    │ value feedback from    │                        │        │
# │                    │            │                    │ those who enjoy my     │                        │        │
# │                    │            │                    │ meals, as it helps me  │                        │        │
# │                    │            │                    │ to continuously        │                        │        │
# │                    │            │                    │ improve and refine my  │                        │        │
# │                    │            │                    │ cooking.               │                        │        │
# └────────────────────┴────────────┴────────────────────┴────────────────────────┴────────────────────────┴────────┘

# %% [markdown]
# Notice that agents answer the questions and also provide explanations for their answers.
#
# ### Exploring your results
# You can use our built-in methods to for analyzing and visualizing your results. You can also export them as a Pandas dataframe:

# %%
# Turn the Results object to a pandas dataframe
results.to_pandas()
# Out:
#    agent.agent_name       agent.persona  answer.q1  \
# 0           Agent_1   You are a student          3
# 1           Agent_2      You are a chef          1
# 2           Agent_1   You are a student          2
# 3           Agent_3  You are an athlete          5
# 4           Agent_2      You are a chef          5
# 5           Agent_2      You are a chef          5
# 6           Agent_1   You are a student          4
# 7           Agent_3  You are an athlete          1
# 8           Agent_3  You are an athlete          1
# 9           Agent_1   You are a student          4
# 10          Agent_2      You are a chef          4
# 11          Agent_2      You are a chef          3
# 12          Agent_3  You are an athlete          3
# 13          Agent_1   You are a student          5
# 14          Agent_1   You are a student          4
# 15          Agent_3  You are an athlete          5
# 16          Agent_3  You are an athlete          4
# 17          Agent_2      You are a chef          5
#
#                                     answer.q1_comment  \
# 0   I enjoy exercising moderately, it helps me sta...
# 1   As a chef, I enjoy cooking and creating delici...
# 2   I enjoy cooking a moderate amount, it's a fun ...
# 3   I enjoy exercising a lot. It helps me stay fit...
# 4   I absolutely love cooking. It's my passion and...
# 5   I enjoy reading a lot, it allows me to discove...
# 6   I really enjoy reading, it helps me relax and ...
# 7   I enjoy reading a little bit, so I'll choose o...
# 8   I enjoy cooking a little bit, but it's not my ...
# 9   I really enjoy exercising as it helps me to st...
# 10  I really enjoy reading, especially when it com...
# 11  I enjoy exercising to a moderate extent. It's ...
# 12  I enjoy cooking to a moderate extent. It's a g...
# 13  I really enjoy reading; it's a great way to le...
# 14  I really enjoy cooking as it's a relaxing and ...
# 15  I absolutely love exercising; it's a crucial p...
# 16  I really enjoy reading as it helps me relax an...
# 17  As a chef, cooking is my passion and I absolut...
#
#                                             answer.q2  iteration.iteration  \
# 0   I try to exercise at least three times a week,...                    0
# 1   As a chef, my job keeps me on my feet for long...                    0
# 2   I enjoy cooking and like to experiment with ne...                    0
# 3   I exercise regularly to maintain my fitness le...                    0
# 4   As a chef, I have developed a routine of plann...                    0
# 5   As a chef, I enjoy reading cookbooks, food mag...                    0
# 6   I try to read for at least 30 minutes every da...                    0
# 7   As an athlete, I prioritize reading materials ...                    0
# 8   As an athlete, I prioritize healthy eating and...                    0
# 9   I usually exercise about four to five times a ...                    0
# 10  As a chef, my reading habits are largely cente...                    0
# 11  As a chef, my schedule can be quite hectic, bu...                    0
# 12  As an athlete, my cooking habits are largely f...                    0
# 13  I have a pretty consistent reading habit. I us...                    0
# 14  I usually cook at home a few times a week, oft...                    0
# 15  My exercise routine is quite structured and co...                    0
# 16  As an athlete, I have a pretty busy schedule f...                    0
# 17  As a chef, I maintain a series of habits that ...                    0
#
#     model.frequency_penalty  model.logprobs  model.max_tokens  \
# 0                         0           False              1000
# 1                         0           False              1000
# 2                         0           False              1000
# 3                         0           False              1000
# 4                         0           False              1000
# 5                         0           False              1000
# 6                         0           False              1000
# 7                         0           False              1000
# 8                         0           False              1000
# 9                         0           False              1000
# 10                        0           False              1000
# 11                        0           False              1000
# 12                        0           False              1000
# 13                        0           False              1000
# 14                        0           False              1000
# 15                        0           False              1000
# 16                        0           False              1000
# 17                        0           False              1000
#
#            model.model  ...  model.temperature  model.top_logprobs  \
# 0        gpt-3.5-turbo  ...                0.5                   3
# 1        gpt-3.5-turbo  ...                0.5                   3
# 2        gpt-3.5-turbo  ...                0.5                   3
# 3        gpt-3.5-turbo  ...                0.5                   3
# 4        gpt-3.5-turbo  ...                0.5                   3
# 5        gpt-3.5-turbo  ...                0.5                   3
# 6        gpt-3.5-turbo  ...                0.5                   3
# 7        gpt-3.5-turbo  ...                0.5                   3
# 8        gpt-3.5-turbo  ...                0.5                   3
# 9   gpt-4-1106-preview  ...                0.5                   3
# 10  gpt-4-1106-preview  ...                0.5                   3
# 11  gpt-4-1106-preview  ...                0.5                   3
# 12  gpt-4-1106-preview  ...                0.5                   3
# 13  gpt-4-1106-preview  ...                0.5                   3
# 14  gpt-4-1106-preview  ...                0.5                   3
# 15  gpt-4-1106-preview  ...                0.5                   3
# 16  gpt-4-1106-preview  ...                0.5                   3
# 17  gpt-4-1106-preview  ...                0.5                   3
#
#     model.top_p                            prompt.q1_system_prompt  \
# 0             1  {'text': "You are answering questions as if yo...
# 1             1  {'text': "You are answering questions as if yo...
# 2             1  {'text': "You are answering questions as if yo...
# 3             1  {'text': "You are answering questions as if yo...
# 4             1  {'text': "You are answering questions as if yo...
# 5             1  {'text': "You are answering questions as if yo...
# 6             1  {'text': "You are answering questions as if yo...
# 7             1  {'text': "You are answering questions as if yo...
# 8             1  {'text': "You are answering questions as if yo...
# 9             1  {'text': "You are answering questions as if yo...
# 10            1  {'text': "You are answering questions as if yo...
# 11            1  {'text': "You are answering questions as if yo...
# 12            1  {'text': "You are answering questions as if yo...
# 13            1  {'text': "You are answering questions as if yo...
# 14            1  {'text': "You are answering questions as if yo...
# 15            1  {'text': "You are answering questions as if yo...
# 16            1  {'text': "You are answering questions as if yo...
# 17            1  {'text': "You are answering questions as if yo...
#
#                                 prompt.q1_user_prompt  \
# 0   {'text': 'You are being asked the following qu...
# 1   {'text': 'You are being asked the following qu...
# 2   {'text': 'You are being asked the following qu...
# 3   {'text': 'You are being asked the following qu...
# 4   {'text': 'You are being asked the following qu...
# 5   {'text': 'You are being asked the following qu...
# 6   {'text': 'You are being asked the following qu...
# 7   {'text': 'You are being asked the following qu...
# 8   {'text': 'You are being asked the following qu...
# 9   {'text': 'You are being asked the following qu...
# 10  {'text': 'You are being asked the following qu...
# 11  {'text': 'You are being asked the following qu...
# 12  {'text': 'You are being asked the following qu...
# 13  {'text': 'You are being asked the following qu...
# 14  {'text': 'You are being asked the following qu...
# 15  {'text': 'You are being asked the following qu...
# 16  {'text': 'You are being asked the following qu...
# 17  {'text': 'You are being asked the following qu...
#
#                               prompt.q2_system_prompt  \
# 0   {'text': "You are answering questions as if yo...
# 1   {'text': "You are answering questions as if yo...
# 2   {'text': "You are answering questions as if yo...
# 3   {'text': "You are answering questions as if yo...
# 4   {'text': "You are answering questions as if yo...
# 5   {'text': "You are answering questions as if yo...
# 6   {'text': "You are answering questions as if yo...
# 7   {'text': "You are answering questions as if yo...
# 8   {'text': "You are answering questions as if yo...
# 9   {'text': "You are answering questions as if yo...
# 10  {'text': "You are answering questions as if yo...
# 11  {'text': "You are answering questions as if yo...
# 12  {'text': "You are answering questions as if yo...
# 13  {'text': "You are answering questions as if yo...
# 14  {'text': "You are answering questions as if yo...
# 15  {'text': "You are answering questions as if yo...
# 16  {'text': "You are answering questions as if yo...
# 17  {'text': "You are answering questions as if yo...
#
#                                 prompt.q2_user_prompt  \
# 0   {'text': 'You are being asked the following qu...
# 1   {'text': 'You are being asked the following qu...
# 2   {'text': 'You are being asked the following qu...
# 3   {'text': 'You are being asked the following qu...
# 4   {'text': 'You are being asked the following qu...
# 5   {'text': 'You are being asked the following qu...
# 6   {'text': 'You are being asked the following qu...
# 7   {'text': 'You are being asked the following qu...
# 8   {'text': 'You are being asked the following qu...
# 9   {'text': 'You are being asked the following qu...
# 10  {'text': 'You are being asked the following qu...
# 11  {'text': 'You are being asked the following qu...
# 12  {'text': 'You are being asked the following qu...
# 13  {'text': 'You are being asked the following qu...
# 14  {'text': 'You are being asked the following qu...
# 15  {'text': 'You are being asked the following qu...
# 16  {'text': 'You are being asked the following qu...
# 17  {'text': 'You are being asked the following qu...
#
#              raw_model_response.q1_raw_model_response  \
# 0   {'id': 'chatcmpl-9Ca1BFWiej2odqhesoQyInWN7wjj9...
# 1   {'id': 'chatcmpl-9Ca1B1JlDKcn3j74QXsGbB1k4TmNo...
# 2   {'id': 'chatcmpl-9Ca1BCHU5EWmdq8njlSdfpWzFtpFW...
# 3   {'id': 'chatcmpl-9Ca1B4XjHTuAUbaL6wiIovdApOiR6...
# 4   {'id': 'chatcmpl-9Ca1BId8HMuj7u93iwcgkrcyGEsGg...
# 5   {'id': 'chatcmpl-9Ca1BtnDbVTovhkc93n1AhgIQcmAT...
# 6   {'id': 'chatcmpl-9Ca1BSpP7wTw2XyXG22Wv9IMmVAOU...
# 7   {'id': 'chatcmpl-9Ca1BAeS3G17x35GFx8YZ5AJLsRB6...
# 8   {'id': 'chatcmpl-9Ca1BUSLeph4S1tERs6Kwkh8qGrwL...
# 9   {'id': 'chatcmpl-9Ca1BMbc9NMCCCpt5hoY1Ojpi5Ir0...
# 10  {'id': 'chatcmpl-9Ca1BQONLqKPodoQjmOiXEOBNb8BV...
# 11  {'id': 'chatcmpl-9Ca1BIvCWs7hDVLmhbdoxcWvFTcMY...
# 12  {'id': 'chatcmpl-9Ca1BrTcEJ5KK0jZYjy8N6ULyRMQ9...
# 13  {'id': 'chatcmpl-9Ca1BGRUL7mfx6rg5NuBYyfNsKmay...
# 14  {'id': 'chatcmpl-9Ca1Bu3s3cNZADdwVHaLsrm8sX9y0...
# 15  {'id': 'chatcmpl-9Ca1BQVXLIT6JGPkon1NIj9WkBqaG...
# 16  {'id': 'chatcmpl-9Ca1BN4X80FkVnPp4K8JFPtRoDnJ6...
# 17  {'id': 'chatcmpl-9Ca1BlzBOC3Ff9nNPCJJd1pqOtFlT...
#
#              raw_model_response.q2_raw_model_response scenario.activity
# 0   {'id': 'chatcmpl-9CaVj6V9cObwIhyd2sGCn5CS1Pkk8...        exercising
# 1   {'id': 'chatcmpl-9CaVjB99PfttdgtQQrdtu5ZLeYVHw...        exercising
# 2   {'id': 'chatcmpl-9CaVj253qpsXzbwWhdz6RkZOdc3RJ...           cooking
# 3   {'id': 'chatcmpl-9CaVjLIP0kGyHrtpOEahkQ7hqjaIl...        exercising
# 4   {'id': 'chatcmpl-9CaVkivSkXLpsKjSicJkUYngc9WoM...           cooking
# 5   {'id': 'chatcmpl-9CaVkKHstxPRlZQHbAzfWzQbMGqsU...           reading
# 6   {'id': 'chatcmpl-9CaVjGfBiiP5ptNlqbRdT84ui9PWn...           reading
# 7   {'id': 'chatcmpl-9CaVj0h5Pkzu58WHRJlYNr78S4eQL...           reading
# 8   {'id': 'chatcmpl-9CaVjniZGGSA3Wa3d70LkB1kJP247...           cooking
# 9   {'id': 'chatcmpl-9CaVjP1gSb08sgCCfZr1M9VWz1cfO...        exercising
# 10  {'id': 'chatcmpl-9CaVjWf9o6etdqQ4Q6LTXPBaQxIAv...           reading
# 11  {'id': 'chatcmpl-9CaVjOFFLepbDn9mymiLymaprHHMy...        exercising
# 12  {'id': 'chatcmpl-9CaVjrb7DDnIsZCv3bF6pqxeAnOq9...           cooking
# 13  {'id': 'chatcmpl-9CaVjOz808pAqRzYLUBWbqY3c8opZ...           reading
# 14  {'id': 'chatcmpl-9CaVkvS4U8oaZ612lutrLsHtJzYvv...           cooking
# 15  {'id': 'chatcmpl-9CaVjVHpoZUcmXzTxGOTxNB1T49ll...        exercising
# 16  {'id': 'chatcmpl-9CaVjRUQJEvb9ve6ARk9irrSn8cY0...           reading
# 17  {'id': 'chatcmpl-9CaVk5oVmbAOC2VZRyHrviCYfgFNt...           cooking
#
# [18 rows x 21 columns]

# %%
# The Results object has various attributes you can use
results.columns
# Out:
# ['agent.agent_name',
#  'agent.persona',
#  'answer.q1',
#  'answer.q1_comment',
#  'answer.q2',
#  'iteration.iteration',
#  'model.frequency_penalty',
#  'model.logprobs',
#  'model.max_tokens',
#  'model.model',
#  'model.presence_penalty',
#  'model.temperature',
#  'model.top_logprobs',
#  'model.top_p',
#  'prompt.q1_system_prompt',
#  'prompt.q1_user_prompt',
#  'prompt.q2_system_prompt',
#  'prompt.q2_user_prompt',
#  'raw_model_response.q1_raw_model_response',
#  'raw_model_response.q2_raw_model_response',
#  'scenario.activity']

# %%
# The Results object also supports SQL-like queries
results.sql("select * from self", shape="wide")
# Out:
#    agent.agent_name       agent.persona  answer.q1  \
# 0           Agent_1   You are a student          3
# 1           Agent_2      You are a chef          1
# 2           Agent_1   You are a student          2
# 3           Agent_3  You are an athlete          5
# 4           Agent_2      You are a chef          5
# 5           Agent_2      You are a chef          5
# 6           Agent_1   You are a student          4
# 7           Agent_3  You are an athlete          1
# 8           Agent_3  You are an athlete          1
# 9           Agent_1   You are a student          4
# 10          Agent_2      You are a chef          4
# 11          Agent_2      You are a chef          3
# 12          Agent_3  You are an athlete          3
# 13          Agent_1   You are a student          5
# 14          Agent_1   You are a student          4
# 15          Agent_3  You are an athlete          5
# 16          Agent_3  You are an athlete          4
# 17          Agent_2      You are a chef          5
#
#                                     answer.q1_comment  \
# 0   I enjoy exercising moderately, it helps me sta...
# 1   As a chef, I enjoy cooking and creating delici...
# 2   I enjoy cooking a moderate amount, it's a fun ...
# 3   I enjoy exercising a lot. It helps me stay fit...
# 4   I absolutely love cooking. It's my passion and...
# 5   I enjoy reading a lot, it allows me to discove...
# 6   I really enjoy reading, it helps me relax and ...
# 7   I enjoy reading a little bit, so I'll choose o...
# 8   I enjoy cooking a little bit, but it's not my ...
# 9   I really enjoy exercising as it helps me to st...
# 10  I really enjoy reading, especially when it com...
# 11  I enjoy exercising to a moderate extent. It's ...
# 12  I enjoy cooking to a moderate extent. It's a g...
# 13  I really enjoy reading; it's a great way to le...
# 14  I really enjoy cooking as it's a relaxing and ...
# 15  I absolutely love exercising; it's a crucial p...
# 16  I really enjoy reading as it helps me relax an...
# 17  As a chef, cooking is my passion and I absolut...
#
#                                             answer.q2  iteration.iteration  \
# 0   I try to exercise at least three times a week,...                    0
# 1   As a chef, my job keeps me on my feet for long...                    0
# 2   I enjoy cooking and like to experiment with ne...                    0
# 3   I exercise regularly to maintain my fitness le...                    0
# 4   As a chef, I have developed a routine of plann...                    0
# 5   As a chef, I enjoy reading cookbooks, food mag...                    0
# 6   I try to read for at least 30 minutes every da...                    0
# 7   As an athlete, I prioritize reading materials ...                    0
# 8   As an athlete, I prioritize healthy eating and...                    0
# 9   I usually exercise about four to five times a ...                    0
# 10  As a chef, my reading habits are largely cente...                    0
# 11  As a chef, my schedule can be quite hectic, bu...                    0
# 12  As an athlete, my cooking habits are largely f...                    0
# 13  I have a pretty consistent reading habit. I us...                    0
# 14  I usually cook at home a few times a week, oft...                    0
# 15  My exercise routine is quite structured and co...                    0
# 16  As an athlete, I have a pretty busy schedule f...                    0
# 17  As a chef, I maintain a series of habits that ...                    0
#
#     model.frequency_penalty  model.logprobs  model.max_tokens  \
# 0                         0               0              1000
# 1                         0               0              1000
# 2                         0               0              1000
# 3                         0               0              1000
# 4                         0               0              1000
# 5                         0               0              1000
# 6                         0               0              1000
# 7                         0               0              1000
# 8                         0               0              1000
# 9                         0               0              1000
# 10                        0               0              1000
# 11                        0               0              1000
# 12                        0               0              1000
# 13                        0               0              1000
# 14                        0               0              1000
# 15                        0               0              1000
# 16                        0               0              1000
# 17                        0               0              1000
#
#            model.model  ...  model.temperature  model.top_logprobs  \
# 0        gpt-3.5-turbo  ...                0.5                   3
# 1        gpt-3.5-turbo  ...                0.5                   3
# 2        gpt-3.5-turbo  ...                0.5                   3
# 3        gpt-3.5-turbo  ...                0.5                   3
# 4        gpt-3.5-turbo  ...                0.5                   3
# 5        gpt-3.5-turbo  ...                0.5                   3
# 6        gpt-3.5-turbo  ...                0.5                   3
# 7        gpt-3.5-turbo  ...                0.5                   3
# 8        gpt-3.5-turbo  ...                0.5                   3
# 9   gpt-4-1106-preview  ...                0.5                   3
# 10  gpt-4-1106-preview  ...                0.5                   3
# 11  gpt-4-1106-preview  ...                0.5                   3
# 12  gpt-4-1106-preview  ...                0.5                   3
# 13  gpt-4-1106-preview  ...                0.5                   3
# 14  gpt-4-1106-preview  ...                0.5                   3
# 15  gpt-4-1106-preview  ...                0.5                   3
# 16  gpt-4-1106-preview  ...                0.5                   3
# 17  gpt-4-1106-preview  ...                0.5                   3
#
#     model.top_p                            prompt.q1_system_prompt  \
# 0             1  {'text': "You are answering questions as if yo...
# 1             1  {'text': "You are answering questions as if yo...
# 2             1  {'text': "You are answering questions as if yo...
# 3             1  {'text': "You are answering questions as if yo...
# 4             1  {'text': "You are answering questions as if yo...
# 5             1  {'text': "You are answering questions as if yo...
# 6             1  {'text': "You are answering questions as if yo...
# 7             1  {'text': "You are answering questions as if yo...
# 8             1  {'text': "You are answering questions as if yo...
# 9             1  {'text': "You are answering questions as if yo...
# 10            1  {'text': "You are answering questions as if yo...
# 11            1  {'text': "You are answering questions as if yo...
# 12            1  {'text': "You are answering questions as if yo...
# 13            1  {'text': "You are answering questions as if yo...
# 14            1  {'text': "You are answering questions as if yo...
# 15            1  {'text': "You are answering questions as if yo...
# 16            1  {'text': "You are answering questions as if yo...
# 17            1  {'text': "You are answering questions as if yo...
#
#                                 prompt.q1_user_prompt  \
# 0   {'text': 'You are being asked the following qu...
# 1   {'text': 'You are being asked the following qu...
# 2   {'text': 'You are being asked the following qu...
# 3   {'text': 'You are being asked the following qu...
# 4   {'text': 'You are being asked the following qu...
# 5   {'text': 'You are being asked the following qu...
# 6   {'text': 'You are being asked the following qu...
# 7   {'text': 'You are being asked the following qu...
# 8   {'text': 'You are being asked the following qu...
# 9   {'text': 'You are being asked the following qu...
# 10  {'text': 'You are being asked the following qu...
# 11  {'text': 'You are being asked the following qu...
# 12  {'text': 'You are being asked the following qu...
# 13  {'text': 'You are being asked the following qu...
# 14  {'text': 'You are being asked the following qu...
# 15  {'text': 'You are being asked the following qu...
# 16  {'text': 'You are being asked the following qu...
# 17  {'text': 'You are being asked the following qu...
#
#                               prompt.q2_system_prompt  \
# 0   {'text': "You are answering questions as if yo...
# 1   {'text': "You are answering questions as if yo...
# 2   {'text': "You are answering questions as if yo...
# 3   {'text': "You are answering questions as if yo...
# 4   {'text': "You are answering questions as if yo...
# 5   {'text': "You are answering questions as if yo...
# 6   {'text': "You are answering questions as if yo...
# 7   {'text': "You are answering questions as if yo...
# 8   {'text': "You are answering questions as if yo...
# 9   {'text': "You are answering questions as if yo...
# 10  {'text': "You are answering questions as if yo...
# 11  {'text': "You are answering questions as if yo...
# 12  {'text': "You are answering questions as if yo...
# 13  {'text': "You are answering questions as if yo...
# 14  {'text': "You are answering questions as if yo...
# 15  {'text': "You are answering questions as if yo...
# 16  {'text': "You are answering questions as if yo...
# 17  {'text': "You are answering questions as if yo...
#
#                                 prompt.q2_user_prompt  \
# 0   {'text': 'You are being asked the following qu...
# 1   {'text': 'You are being asked the following qu...
# 2   {'text': 'You are being asked the following qu...
# 3   {'text': 'You are being asked the following qu...
# 4   {'text': 'You are being asked the following qu...
# 5   {'text': 'You are being asked the following qu...
# 6   {'text': 'You are being asked the following qu...
# 7   {'text': 'You are being asked the following qu...
# 8   {'text': 'You are being asked the following qu...
# 9   {'text': 'You are being asked the following qu...
# 10  {'text': 'You are being asked the following qu...
# 11  {'text': 'You are being asked the following qu...
# 12  {'text': 'You are being asked the following qu...
# 13  {'text': 'You are being asked the following qu...
# 14  {'text': 'You are being asked the following qu...
# 15  {'text': 'You are being asked the following qu...
# 16  {'text': 'You are being asked the following qu...
# 17  {'text': 'You are being asked the following qu...
#
#              raw_model_response.q1_raw_model_response  \
# 0   {'id': 'chatcmpl-9Ca1BFWiej2odqhesoQyInWN7wjj9...
# 1   {'id': 'chatcmpl-9Ca1B1JlDKcn3j74QXsGbB1k4TmNo...
# 2   {'id': 'chatcmpl-9Ca1BCHU5EWmdq8njlSdfpWzFtpFW...
# 3   {'id': 'chatcmpl-9Ca1B4XjHTuAUbaL6wiIovdApOiR6...
# 4   {'id': 'chatcmpl-9Ca1BId8HMuj7u93iwcgkrcyGEsGg...
# 5   {'id': 'chatcmpl-9Ca1BtnDbVTovhkc93n1AhgIQcmAT...
# 6   {'id': 'chatcmpl-9Ca1BSpP7wTw2XyXG22Wv9IMmVAOU...
# 7   {'id': 'chatcmpl-9Ca1BAeS3G17x35GFx8YZ5AJLsRB6...
# 8   {'id': 'chatcmpl-9Ca1BUSLeph4S1tERs6Kwkh8qGrwL...
# 9   {'id': 'chatcmpl-9Ca1BMbc9NMCCCpt5hoY1Ojpi5Ir0...
# 10  {'id': 'chatcmpl-9Ca1BQONLqKPodoQjmOiXEOBNb8BV...
# 11  {'id': 'chatcmpl-9Ca1BIvCWs7hDVLmhbdoxcWvFTcMY...
# 12  {'id': 'chatcmpl-9Ca1BrTcEJ5KK0jZYjy8N6ULyRMQ9...
# 13  {'id': 'chatcmpl-9Ca1BGRUL7mfx6rg5NuBYyfNsKmay...
# 14  {'id': 'chatcmpl-9Ca1Bu3s3cNZADdwVHaLsrm8sX9y0...
# 15  {'id': 'chatcmpl-9Ca1BQVXLIT6JGPkon1NIj9WkBqaG...
# 16  {'id': 'chatcmpl-9Ca1BN4X80FkVnPp4K8JFPtRoDnJ6...
# 17  {'id': 'chatcmpl-9Ca1BlzBOC3Ff9nNPCJJd1pqOtFlT...
#
#              raw_model_response.q2_raw_model_response scenario.activity
# 0   {'id': 'chatcmpl-9CaVj6V9cObwIhyd2sGCn5CS1Pkk8...        exercising
# 1   {'id': 'chatcmpl-9CaVjB99PfttdgtQQrdtu5ZLeYVHw...        exercising
# 2   {'id': 'chatcmpl-9CaVj253qpsXzbwWhdz6RkZOdc3RJ...           cooking
# 3   {'id': 'chatcmpl-9CaVjLIP0kGyHrtpOEahkQ7hqjaIl...        exercising
# 4   {'id': 'chatcmpl-9CaVkivSkXLpsKjSicJkUYngc9WoM...           cooking
# 5   {'id': 'chatcmpl-9CaVkKHstxPRlZQHbAzfWzQbMGqsU...           reading
# 6   {'id': 'chatcmpl-9CaVjGfBiiP5ptNlqbRdT84ui9PWn...           reading
# 7   {'id': 'chatcmpl-9CaVj0h5Pkzu58WHRJlYNr78S4eQL...           reading
# 8   {'id': 'chatcmpl-9CaVjniZGGSA3Wa3d70LkB1kJP247...           cooking
# 9   {'id': 'chatcmpl-9CaVjP1gSb08sgCCfZr1M9VWz1cfO...        exercising
# 10  {'id': 'chatcmpl-9CaVjWf9o6etdqQ4Q6LTXPBaQxIAv...           reading
# 11  {'id': 'chatcmpl-9CaVjOFFLepbDn9mymiLymaprHHMy...        exercising
# 12  {'id': 'chatcmpl-9CaVjrb7DDnIsZCv3bF6pqxeAnOq9...           cooking
# 13  {'id': 'chatcmpl-9CaVjOz808pAqRzYLUBWbqY3c8opZ...           reading
# 14  {'id': 'chatcmpl-9CaVkvS4U8oaZ612lutrLsHtJzYvv...           cooking
# 15  {'id': 'chatcmpl-9CaVjVHpoZUcmXzTxGOTxNB1T49ll...        exercising
# 16  {'id': 'chatcmpl-9CaVjRUQJEvb9ve6ARk9irrSn8cY0...           reading
# 17  {'id': 'chatcmpl-9CaVk5oVmbAOC2VZRyHrviCYfgFNt...           cooking
#
# [18 rows x 21 columns]

# %% [markdown]
# Learn more about use cases and ways to conduct AI-powered research in the <a href="http://localhost:8000/getting-started#edsl-showcase" target="_blank" class="text-blue-500 hover:text-blue-600">EDSL Showcase</a>.

# %% [markdown]
# ---
# <p style="font-size: 14px;">Copyright © 2024 Expected Parrot, Inc. All rights reserved.   <a href="www.expectedparrot.com" style="color:#130061">www.expectedparrot.com</a></p>
