# %% [markdown]
# # Exceptions
# This notebook administers a non-sensical question in order to generate an example exceptions message and report.
#
# ## Help debugging
# We also show how to [post the notebook](https://docs.expectedparrot.com/en/latest/notebooks.html) to [Coop](https://docs.expectedparrot.com/en/latest/coop.html) which we recommend doing if you would like assistance debugging your exceptions. You can set the visibility of the notebook to public, unlisted or private, and then email us the link to inspect at info@expectedparrot.com

# %%
from edsl import QuestionCheckBox

q = QuestionCheckBox(
    question_name = "bad_instruction",
    question_text = "What is your favorite color?",
    question_options = [1,3,5] # Non-sensical options for the question
)

results = q.run()
# Out:
# Exceptions were raised in 1 out of 1 interviews.
# <a href="/files//Users/a16174/edsl/docs/notebooks/tmpleta08m9.html" target="_blank">Open report to see details.</a>
# "
#             <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Exception Details&lt;/title&gt;
#     &lt;style&gt;
#     body {
#     font-family: Arial, sans-serif;
#     line-height: 1.6;
#     background-color: #f9f9f9;
#     color: #333;
#     margin: 20px;
# }
#
# .interview {
#     font-size: 1.5em;
#     margin-bottom: 10px;
#     padding: 10px;
#     background-color: #e3f2fd;
#     border-left: 5px solid #2196f3;
# }
#
# .question {
#     font-size: 1.2em;
#     margin-bottom: 10px;
#     padding: 10px;
#     background-color: #fff9c4;
#     border-left: 5px solid #ffeb3b;
# }
#
# .exception-detail {
# ...

# %%
from edsl import Notebook

n = Notebook(path = "exceptions_example.ipynb")

n.push(description="Example exception message and report", visibility="public")
# Out:
# {'description': 'Example exception message and report',
#  'object_type': 'notebook',
#  'url': 'https://www.expectedparrot.com/content/fa867e1e-9f20-4a0b-8534-5c400a9f9fdf',
#  'uuid': 'fa867e1e-9f20-4a0b-8534-5c400a9f9fdf',
#  'version': '0.1.33.dev1',
#  'visibility': 'public'}

# %% [markdown]
# To update an object:

# %%
n = Notebook(path = "exceptions_example.ipynb") # resave it

# %%
n.patch(uuid = "fa867e1e-9f20-4a0b-8534-5c400a9f9fdf", value = n)
# Out:
# {'status': 'success'}
